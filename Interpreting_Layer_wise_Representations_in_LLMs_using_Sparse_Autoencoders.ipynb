# %%
# @title Installing  conllu
# !pip install conllu
# Out:
# Collecting conllu
#   Downloading conllu-6.0.0-py3-none-any.whl.metadata (21 kB)
# Downloading conllu-6.0.0-py3-none-any.whl (16 kB)
# Installing collected packages: conllu
# Successfully installed conllu-6.0.0

# %%
# @title importing required modules
import torch
import numpy as np
import pandas as pd
from transformers import AutoTokenizer, AutoModel
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score
import json
import os

# %%
# @title Function to input from user about model
def get_user_model_choice():
        print("Available model options:")
        models = {
            '1': 'distilbert-base-uncased',
            '2': 'bert-base-uncased',
            '3': 'gpt2',
            '4': 'microsoft/DialoGPT-medium',
            '5': 'google/electra-small-discriminator',
            '6': 'facebook/opt-350m',
            '7': 'custom'
        }

        for key, value in models.items():
            print(f"{key}: {value}")

        choice = input("Enter your choice (1-7): ").strip()

        if choice == '7':
            model_name = input("Enter custom model name from HuggingFace: ").strip()
            return model_name
        elif choice in models:
            return models[choice]
        else:
            print("Invalid choice, using default DistilBERT")
            return 'distilbert-base-uncased'

# %%
# @title Function to find the attribute of getting no. of layers
def _get_num_layers(model):
        #has_attr or has attribute checks whether this attribute is available in the model or not4
        if hasattr(model.config, 'n_layers'):
            return model.config.n_layers
        elif hasattr(model.config, 'num_hidden_layers'):
            return model.config.num_hidden_layers
        elif hasattr(model.config, 'n_layer'):
            return model.config.n_layer
        else:
            print("Not able to find")

# %%
# @title Model initialization Phase
model_name = get_user_model_choice()
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name, output_hidden_states=False,attn_implementation="eager", output_attentions=True)
model.eval()
label_encoder = LabelEncoder()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)
num_layers = _get_num_layers(model)
if tokenizer.pad_token is None:
  tokenizer.pad_token = tokenizer.eos_token
# Out:
# Available model options:
# 1: distilbert-base-uncased
# 2: bert-base-uncased
# 3: gpt2
# 4: microsoft/DialoGPT-medium
# 5: google/electra-small-discriminator
# 6: facebook/opt-350m
# 7: custom
# Enter your choice (1-7): 1
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]

# %%
# @title Code to prepare the dataset, need to manually set the max label count
from itertools import chain
from collections import defaultdict
import requests
from io import StringIO
from conllu import parse_incr
import re

def prepare_data(links,max_per_label):
    # Define grouping mappings
    POS_GROUPS = {
        # Keep separate - content words
        'NOUN': 'NOUN',
        'VERB': 'VERB',
        'ADJ': 'ADJ',
        'ADV': 'ADV',
        'PROPN': 'PROPN',
        'NUM': 'NUM',

        # Group together - function words
        'PART': 'GRAMMAR',
        'CCONJ': 'GRAMMAR',
        'DET': 'GRAMMAR',
        'SCONJ': 'GRAMMAR',
        'INTJ': 'GRAMMAR',
        'X': 'GRAMMAR',
        'SYM': 'GRAMMAR',
        'AUX': 'GRAMMAR',
        'ADP': 'GRAMMAR',
        'PRON': 'GRAMMAR',
        'PUNCT': 'GRAMMAR'
    }

    DEP_GROUPS = {
        # Core Arguments
        'nsubj': 'ARGUMENT', 'nsubj:pass': 'ARGUMENT', 'obj': 'ARGUMENT',
        'iobj': 'ARGUMENT', 'ccomp': 'ARGUMENT', 'xcomp': 'ARGUMENT',
        'expl': 'ARGUMENT', 'csubj': 'ARGUMENT', 'csubj:pass': 'ARGUMENT',
        'csubj:outer': 'ARGUMENT', 'nsubj:outer': 'ARGUMENT',

        # Modifiers
        'amod': 'MODIFIER', 'advmod': 'MODIFIER', 'obl': 'MODIFIER',
        'obl:agent': 'MODIFIER', 'obl:unmarked': 'MODIFIER', 'nmod': 'MODIFIER',
        'nmod:poss': 'MODIFIER', 'nmod:unmarked': 'MODIFIER', 'nmod:desc': 'MODIFIER',
        'nummod': 'MODIFIER', 'appos': 'MODIFIER', 'vocative': 'MODIFIER',
        'dislocated': 'MODIFIER', 'orphan': 'MODIFIER',

        # Clause Linking
        'advcl': 'CLAUSE_LINK', 'advcl:relcl': 'CLAUSE_LINK', 'acl': 'CLAUSE_LINK',
        'acl:relcl': 'CLAUSE_LINK', 'mark': 'CLAUSE_LINK',

        # Coordination
        'conj': 'COORD', 'cc': 'COORD', 'cc:preconj': 'COORD',
        'parataxis': 'COORD', 'list': 'COORD',

        # Function Words
        'aux': 'FUNC', 'aux:pass': 'FUNC', 'cop': 'FUNC', 'case': 'FUNC',
        'det': 'FUNC', 'det:predet': 'FUNC', 'compound': 'FUNC',
        'compound:prt': 'FUNC', 'fixed': 'FUNC', 'flat': 'FUNC',
        'goeswith': 'FUNC', 'dep': 'FUNC',

        # Discourse & Root
        'discourse': 'DISCOURSE', 'reparandum': 'DISCOURSE', 'root': 'ROOT',

        # Punctuation (separate from others)
        'punct': 'PUNCT'
    }
    def is_valid_word(word):
      """Filter out tokens that are not meaningful words."""
      try:
        if len(word) <= 2 or not word.isalpha():
          return False
      except Exception as e:
        print(type(word))
      if re.search(r'(.)\1{2,}', word):  # any char repeated more than 3 times
          return False
      if re.search(r'(http|www\.|\.com|\.org|\.net)', word):
          return False
      if re.search(r'[^a-zA-Z]', word):  # only allow pure alphabets
          return False
      if re.match(r'^[!@#$%^&*()_+\-=\[\]{};\':"\\|,.<>/?`~]+$', word):
          return False
      if word.startswith('#'):
          return False
      if re.match(r'^[\d\W]+$', word):
          return False
      return True

    def prepare_data_from_each(link):
        response = requests.get(link)
        file_content = StringIO(response.text)
        sentences = []
        pos_labels = []
        dep_labels = []
        position_labels = []

        for tokenlist in parse_incr(file_content):
            if not tokenlist:
                continue
            tokens, pos, dep = [], [], []
            for token in tokenlist:
                if isinstance(token["id"], int) and token["form"] is not None and is_valid_word(token['form']):
                    tokens.append(token["form"])
                    pos_group = POS_GROUPS.get(token["upos"], 'OTHER')
                    dep_group = DEP_GROUPS.get(token["deprel"], 'OTHER')
                    pos.append(pos_group)
                    dep.append(dep_group)

            if tokens:
                sentences.append(" ".join(tokens))
                pos_labels.append(pos)
                dep_labels.append(dep)
                position_labels.append(list(range(len(tokens))))
            # if(len(sentences)==100):
            #   break
        return {'pos': sentences.copy(), 'dep': sentences.copy()}, {'pos': pos_labels, 'dep': dep_labels}




    from collections import defaultdict

    def filter_redundant_word_label_pairs(all_sentences, all_labels, max_per_label):
        """
        Filters redundant (word, label) pairs for any task (e.g., pos, dep),
        and caps the number of tokens per label using max_per_label.
        """
        seen = defaultdict(set)
        label_counter = defaultdict(lambda: defaultdict(int))
        filtered_sentences = defaultdict(list)
        filtered_labels = defaultdict(list)

        for task in all_labels:
            for sentence, label_list in zip(all_sentences[task], all_labels[task]):
                words = sentence.split()

                new_words = []
                new_task_labels = []

                for word, label in zip(words, label_list):
                    word_lower = word.lower()
                    pair = (word_lower, label)

                    if pair not in seen[task] and label_counter[task][label] < max_per_label[task]:
                        new_words.append(word)
                        new_task_labels.append(label)
                        seen[task].add(pair)
                        label_counter[task][label] += 1

                if new_words:
                    filtered_sentences[task].append(" ".join(new_words))
                    filtered_labels[task].append(new_task_labels)

        return filtered_sentences, filtered_labels




    # Collect all data
    all_sentences = defaultdict(list)
    all_labels = {'pos': [], 'dep': []}

    for each_link in links:
        each_sentences, each_labels_dict = prepare_data_from_each(each_link)
        for task in each_labels_dict:
            all_sentences[task].extend(each_sentences[task])
            all_labels[task].extend(each_labels_dict[task])



    all_sentences, all_labels=filter_redundant_word_label_pairs(all_sentences, all_labels,max_per_label)
    return all_sentences,all_labels

# %%
train_links=[
    "https://raw.githubusercontent.com/UniversalDependencies/UD_English-EWT/master/en_ewt-ud-dev.conllu",
    "https://raw.githubusercontent.com/UniversalDependencies/UD_English-LinES/master/en_lines-ud-train.conllu",
    "https://raw.githubusercontent.com/UniversalDependencies/UD_English-GUM/master/en_gum-ud-dev.conllu",
    "https://raw.githubusercontent.com/UniversalDependencies/UD_English-GUM/master/en_gum-ud-train.conllu",
    "https://raw.githubusercontent.com/UniversalDependencies/UD_English-LinES/master/en_lines-ud-train.conllu",
    "https://raw.githubusercontent.com/UniversalDependencies/UD_English-LinES/master/en_lines-ud-dev.conllu",

    "https://raw.githubusercontent.com/UniversalDependencies/UD_English-ParTUT/master/en_partut-ud-dev.conllu",
    "https://raw.githubusercontent.com/UniversalDependencies/UD_English-ParTUT/master/en_partut-ud-train.conllu",
    "https://raw.githubusercontent.com/UniversalDependencies/UD_English-Atis/master/en_atis-ud-train.conllu",
    "https://raw.githubusercontent.com/UniversalDependencies/UD_English-Atis/master/en_atis-ud-dev.conllu",

    #count0
    # "https://raw.githubusercontent.com/UniversalDependencies/UD_English-GUMReddit/master/en_gumreddit-ud-train.conllu",
    # "https://raw.githubusercontent.com/UniversalDependencies/UD_English-GUMReddit/master/en_gumreddit-ud-dev.conllu",
    ]
max_per_label={'pos':1000,'dep':1000}
train_all_sentences,train_all_labels=prepare_data(train_links,max_per_label)

# %%
# @title Code to display example of processed dataset
for i in range(8):
  for each_task in train_all_sentences:
    if(len(train_all_labels['pos'][i])!=len(train_all_labels['dep'][i])):
      print(train_all_sentences["pos"][i])
      print(train_all_labels['pos'][i])
      print(train_all_sentences["dep"][i])
      print(train_all_labels['dep'][i])
      print('-------------------\n')
# Out:
# also Noel Anketell Kramer Appeals John Montague Steadman
# ['ADV', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN']
# also Noel Anketell Kramer District Appeals John Montague Steadman
# ['MODIFIER', 'FUNC', 'FUNC', 'FUNC', 'FUNC', 'MODIFIER', 'ARGUMENT', 'FUNC', 'FUNC']
# -------------------
#
# also Noel Anketell Kramer Appeals John Montague Steadman
# ['ADV', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN']
# also Noel Anketell Kramer District Appeals John Montague Steadman
# ['MODIFIER', 'FUNC', 'FUNC', 'FUNC', 'FUNC', 'MODIFIER', 'ARGUMENT', 'FUNC', 'FUNC']
# -------------------

# %%
# @title function to count the repitions of unique labels
from collections import Counter, defaultdict

def count_label_frequencies_per_task(labels_dict):
    """
    Returns a dict: task → Counter of label frequencies
    Example: {'pos': Counter({'NOUN': 120, 'VERB': 98, ...})}
    """
    task_label_frequencies = defaultdict(Counter)

    for task, all_label_lists in labels_dict.items():
        for sentence_labels in all_label_lists:
            task_label_frequencies[task].update(sentence_labels)

    return task_label_frequencies

# %%
# @title Code to compute count of each unique label within task
def display(label_freqs):
  for task, counter in label_freqs.items():
    print(f"\nLabel frequencies for task '{task}':")
    for label, count in counter.most_common():
        print(f"  {label}: {count}")


label_freqs = count_label_frequencies_per_task(train_all_labels)
display(label_freqs)
# Out:
# Label frequencies for task 'pos':
#   VERB: 1000
#   NOUN: 1000
#   PROPN: 1000
#   ADJ: 1000
#   ADV: 982
#   GRAMMAR: 555
#   NUM: 40
#
# Label frequencies for task 'dep':
#   FUNC: 1000
#   ROOT: 1000
#   ARGUMENT: 1000
#   MODIFIER: 1000
#   CLAUSE_LINK: 1000
#   COORD: 1000
#   DISCOURSE: 257
#   OTHER: 97
#   PUNCT: 1

# %%
# @title Function to align tokens with labels
def _align_tokens_with_labels(sentences, labels, all_tokens, task_type, start_idx=0):
    aligned_data = []

    for batch_sent_idx, (sentence, original_labels, tokens) in enumerate(zip(sentences, labels, all_tokens)):
        sent_idx = start_idx + batch_sent_idx
        original_words = sentence.split()
        word_idx = 0

        for token_idx, token in enumerate(tokens):
            # 🚫 Skip special and pad tokens
            if token in ['[CLS]', '[SEP]', '[PAD]', '<s>', '</s>', '<pad>']:
                continue

            # 🔗 Handle subword tokens (e.g., ##word)
            if token.startswith('##'):
                if aligned_data and aligned_data[-1]['sentence_idx'] == sent_idx:
                    label = aligned_data[-1]['label']
                else:
                    label = original_labels[word_idx] if word_idx < len(original_labels) else 'O'
            else:
                if word_idx < len(original_labels):
                    label = original_labels[word_idx]
                    word_idx += 1
                else:
                    label = 'O'

            aligned_data.append({
                'sentence_idx': sent_idx,
                'token_idx': token_idx,
                'label': label,
                'task': task_type,
                'token': token,
                'batch_sent_idx': batch_sent_idx
            })

    # print(f"Aligned data size (excluding special tokens): {len(aligned_data)}")
    return aligned_data

# %%
# @title Function to extract hidden representations from model
def _extract_representations_(all_task_sentences, labels_dict, tokenizer, num_layers, model, device, test=None):
    all_task_hidden_states = {i:""  for i in all_task_sentences.keys()}
    all_task_tokens = {i:""  for i in all_task_sentences.keys()}
    batch_size = 8

    for each_task in all_task_sentences:
      all_hidden_states = {i: [] for i in range(num_layers)}
      all_tokens = []
      batch_size = 8
      sentences=all_task_sentences[each_task]

      for i in range(0, len(sentences), batch_size):
        batch = sentences[i:i + batch_size]

        encoded = tokenizer(batch, padding=True, truncation=True,
                            max_length=128, return_tensors='pt')

        input_ids = encoded['input_ids'].to(device)
        attention_mask = encoded['attention_mask'].to(device)

        with torch.no_grad():
            outputs = model(input_ids=input_ids, attention_mask=attention_mask, output_hidden_states=True)

            hidden_states = outputs.hidden_states if hasattr(outputs, 'hidden_states') else [outputs.last_hidden_state]

            print(f"{i // batch_size}th batch is processed out of {len(sentences) // batch_size}")

            tokens_batch = [tokenizer.convert_ids_to_tokens(ids) for ids in encoded['input_ids']]
            all_tokens.extend(tokens_batch)  # Save for alignment step

            # Filter and save hidden states layer by layer
            for layer_idx in range(1, len(hidden_states)):  # Skip layer 0 (embedding layer)
                layer_hidden = hidden_states[layer_idx]  # (batch_size, seq_len, hidden_dim)
                filtered_batch = []

                for b in range(len(batch)):
                    sentence_tokens = tokens_batch[b]
                    sentence_hidden = layer_hidden[b]  # (seq_len, hidden_dim)
                    sentence_mask = attention_mask[b]  # (seq_len,)

                    filtered = []

                    for t_idx, (tok, h_vec, attn) in enumerate(zip(sentence_tokens, sentence_hidden, sentence_mask)):
                        if attn == 0:
                            continue  # Skip PAD
                        if tok in ['[CLS]', '[SEP]', '[PAD]', '<s>', '</s>', '<pad>']:
                            continue  # Skip special tokens
                        filtered.append(h_vec.cpu())

                    if filtered:
                        filtered_batch.append(torch.stack(filtered))  # (filtered_seq_len, hidden_dim)
                    else:
                        filtered_batch.append(torch.empty((0, model.config.hidden_size)))  # fallback for empty case

                all_hidden_states[layer_idx - 1].extend(filtered_batch)
      all_task_hidden_states[each_task]=all_hidden_states
      all_task_tokens[each_task]=all_tokens
    print("all batches processed completely")

    # Initialize aligned data for all tasks
    all_task_alignedData = {task_type: [] for task_type in labels_dict.keys()}
    for task_type in labels_dict.keys():
      task_sentences = all_task_sentences[task_type]  # task-specific sentence list
      task_labels = labels_dict[task_type]
      all_tokens=all_task_tokens[task_type]
      for i in range(0, len(task_sentences), batch_size):
          batch_sentences = task_sentences[i:i + batch_size]
          batch_labels = task_labels[i:i + batch_size]
          batch_tokens = all_tokens[i:i + batch_size]

          batch_aligned_data = _align_tokens_with_labels(batch_sentences, batch_labels, batch_tokens, task_type, i)
          all_task_alignedData[task_type].extend(batch_aligned_data)

    return all_task_hidden_states, all_task_alignedData

# %%
train_all_task_hidden_states,train_all_task_alignedData =  _extract_representations_(
        train_all_sentences,
        train_all_labels,
        tokenizer,
        num_layers,
        model,
        device
    )
# Out:
# 0th batch is processed out of 316
# 1th batch is processed out of 316
# 2th batch is processed out of 316
# 3th batch is processed out of 316
# 4th batch is processed out of 316
# 5th batch is processed out of 316
# 6th batch is processed out of 316
# 7th batch is processed out of 316
# 8th batch is processed out of 316
# 9th batch is processed out of 316
# 10th batch is processed out of 316
# 11th batch is processed out of 316
# 12th batch is processed out of 316
# 13th batch is processed out of 316
# 14th batch is processed out of 316
# 15th batch is processed out of 316
# 16th batch is processed out of 316
# 17th batch is processed out of 316
# 18th batch is processed out of 316
# 19th batch is processed out of 316
# 20th batch is processed out of 316
# 21th batch is processed out of 316
# 22th batch is processed out of 316
# 23th batch is processed out of 316
# 24th batch is processed out of 316
# 25th batch is processed out of 316
# 26th batch is processed out of 316
# 27th batch is processed out of 316
# 28th batch is processed out of 316
# 29th batch is processed out of 316
# 30th batch is processed out of 316
# 31th batch is processed out of 316
# 32th batch is processed out of 316
# 33th batch is processed out of 316
# 34th batch is processed out of 316
# 35th batch is processed out of 316
# 36th batch is processed out of 316
# 37th batch is processed out of 316
# 38th batch is processed out of 316
# 39th batch is processed out of 316
# 40th batch is processed out of 316
# 41th batch is processed out of 316
# 42th batch is processed out of 316
# 43th batch is processed out of 316
# 44th batch is processed out of 316
# 45th batch is processed out of 316
# 46th batch is processed out of 316
# 47th batch is processed out of 316
# 48th batch is processed out of 316
# 49th batch is processed out of 316
# 50th batch is processed out of 316
# 51th batch is processed out of 316
# 52th batch is processed out of 316
# 53th batch is processed out of 316
# 54th batch is processed out of 316
# 55th batch is processed out of 316
# 56th batch is processed out of 316
# 57th batch is processed out of 316
# 58th batch is processed out of 316
# 59th batch is processed out of 316
# 60th batch is processed out of 316
# 61th batch is processed out of 316
# 62th batch is processed out of 316
# 63th batch is processed out of 316
# 64th batch is processed out of 316
# 65th batch is processed out of 316
# 66th batch is processed out of 316
# 67th batch is processed out of 316
# 68th batch is processed out of 316
# 69th batch is processed out of 316
# 70th batch is processed out of 316
# 71th batch is processed out of 316
# 72th batch is processed out of 316
# 73th batch is processed out of 316
# 74th batch is processed out of 316
# 75th batch is processed out of 316
# 76th batch is processed out of 316
# 77th batch is processed out of 316
# 78th batch is processed out of 316
# 79th batch is processed out of 316
# 80th batch is processed out of 316
# 81th batch is processed out of 316
# 82th batch is processed out of 316
# 83th batch is processed out of 316
# 84th batch is processed out of 316
# 85th batch is processed out of 316
# 86th batch is processed out of 316
# 87th batch is processed out of 316
# 88th batch is processed out of 316
# 89th batch is processed out of 316
# 90th batch is processed out of 316
# 91th batch is processed out of 316
# 92th batch is processed out of 316
# 93th batch is processed out of 316
# 94th batch is processed out of 316
# 95th batch is processed out of 316
# 96th batch is processed out of 316
# 97th batch is processed out of 316
# 98th batch is processed out of 316
# 99th batch is processed out of 316
# 100th batch is processed out of 316
# 101th batch is processed out of 316
# 102th batch is processed out of 316
# 103th batch is processed out of 316
# 104th batch is processed out of 316
# 105th batch is processed out of 316
# 106th batch is processed out of 316
# 107th batch is processed out of 316
# 108th batch is processed out of 316
# 109th batch is processed out of 316
# 110th batch is processed out of 316
# 111th batch is processed out of 316
# 112th batch is processed out of 316
# 113th batch is processed out of 316
# 114th batch is processed out of 316
# 115th batch is processed out of 316
# 116th batch is processed out of 316
# 117th batch is processed out of 316
# 118th batch is processed out of 316
# 119th batch is processed out of 316
# 120th batch is processed out of 316
# 121th batch is processed out of 316
# 122th batch is processed out of 316
# 123th batch is processed out of 316
# 124th batch is processed out of 316
# 125th batch is processed out of 316
# 126th batch is processed out of 316
# 127th batch is processed out of 316
# 128th batch is processed out of 316
# 129th batch is processed out of 316
# 130th batch is processed out of 316
# 131th batch is processed out of 316
# 132th batch is processed out of 316
# 133th batch is processed out of 316
# 134th batch is processed out of 316
# 135th batch is processed out of 316
# 136th batch is processed out of 316
# 137th batch is processed out of 316
# 138th batch is processed out of 316
# 139th batch is processed out of 316
# 140th batch is processed out of 316
# 141th batch is processed out of 316
# 142th batch is processed out of 316
# 143th batch is processed out of 316
# 144th batch is processed out of 316
# 145th batch is processed out of 316
# 146th batch is processed out of 316
# 147th batch is processed out of 316
# 148th batch is processed out of 316
# 149th batch is processed out of 316
# 150th batch is processed out of 316
# 151th batch is processed out of 316
# 152th batch is processed out of 316
# 153th batch is processed out of 316
# 154th batch is processed out of 316
# 155th batch is processed out of 316
# 156th batch is processed out of 316
# 157th batch is processed out of 316
# 158th batch is processed out of 316
# 159th batch is processed out of 316
# 160th batch is processed out of 316
# 161th batch is processed out of 316
# 162th batch is processed out of 316
# 163th batch is processed out of 316
# 164th batch is processed out of 316
# 165th batch is processed out of 316
# 166th batch is processed out of 316
# 167th batch is processed out of 316
# 168th batch is processed out of 316
# 169th batch is processed out of 316
# 170th batch is processed out of 316
# 171th batch is processed out of 316
# 172th batch is processed out of 316
# 173th batch is processed out of 316
# 174th batch is processed out of 316
# 175th batch is processed out of 316
# 176th batch is processed out of 316
# 177th batch is processed out of 316
# 178th batch is processed out of 316
# 179th batch is processed out of 316
# 180th batch is processed out of 316
# 181th batch is processed out of 316
# 182th batch is processed out of 316
# 183th batch is processed out of 316
# 184th batch is processed out of 316
# 185th batch is processed out of 316
# 186th batch is processed out of 316
# 187th batch is processed out of 316
# 188th batch is processed out of 316
# 189th batch is processed out of 316
# 190th batch is processed out of 316
# 191th batch is processed out of 316
# 192th batch is processed out of 316
# 193th batch is processed out of 316
# 194th batch is processed out of 316
# 195th batch is processed out of 316
# 196th batch is processed out of 316
# 197th batch is processed out of 316
# 198th batch is processed out of 316
# 199th batch is processed out of 316
# 200th batch is processed out of 316
# 201th batch is processed out of 316
# 202th batch is processed out of 316
# 203th batch is processed out of 316
# 204th batch is processed out of 316
# 205th batch is processed out of 316
# 206th batch is processed out of 316
# 207th batch is processed out of 316
# 208th batch is processed out of 316
# 209th batch is processed out of 316
# 210th batch is processed out of 316
# 211th batch is processed out of 316
# 212th batch is processed out of 316
# 213th batch is processed out of 316
# 214th batch is processed out of 316
# 215th batch is processed out of 316
# 216th batch is processed out of 316
# 217th batch is processed out of 316
# 218th batch is processed out of 316
# 219th batch is processed out of 316
# 220th batch is processed out of 316
# 221th batch is processed out of 316
# 222th batch is processed out of 316
# 223th batch is processed out of 316
# 224th batch is processed out of 316
# 225th batch is processed out of 316
# 226th batch is processed out of 316
# 227th batch is processed out of 316
# 228th batch is processed out of 316
# 229th batch is processed out of 316
# 230th batch is processed out of 316
# 231th batch is processed out of 316
# 232th batch is processed out of 316
# 233th batch is processed out of 316
# 234th batch is processed out of 316
# 235th batch is processed out of 316
# 236th batch is processed out of 316
# 237th batch is processed out of 316
# 238th batch is processed out of 316
# 239th batch is processed out of 316
# 240th batch is processed out of 316
# 241th batch is processed out of 316
# 242th batch is processed out of 316
# 243th batch is processed out of 316
# 244th batch is processed out of 316
# 245th batch is processed out of 316
# 246th batch is processed out of 316
# 247th batch is processed out of 316
# 248th batch is processed out of 316
# 249th batch is processed out of 316
# 250th batch is processed out of 316
# 251th batch is processed out of 316
# 252th batch is processed out of 316
# 253th batch is processed out of 316
# 254th batch is processed out of 316
# 255th batch is processed out of 316
# 256th batch is processed out of 316
# 257th batch is processed out of 316
# 258th batch is processed out of 316
# 259th batch is processed out of 316
# 260th batch is processed out of 316
# 261th batch is processed out of 316
# 262th batch is processed out of 316
# 263th batch is processed out of 316
# 264th batch is processed out of 316
# 265th batch is processed out of 316
# 266th batch is processed out of 316
# 267th batch is processed out of 316
# 268th batch is processed out of 316
# 269th batch is processed out of 316
# 270th batch is processed out of 316
# 271th batch is processed out of 316
# 272th batch is processed out of 316
# 273th batch is processed out of 316
# 274th batch is processed out of 316
# 275th batch is processed out of 316
# 276th batch is processed out of 316
# 277th batch is processed out of 316
# 278th batch is processed out of 316
# 279th batch is processed out of 316
# 280th batch is processed out of 316
# 281th batch is processed out of 316
# 282th batch is processed out of 316
# 283th batch is processed out of 316
# 284th batch is processed out of 316
# 285th batch is processed out of 316
# 286th batch is processed out of 316
# 287th batch is processed out of 316
# 288th batch is processed out of 316
# 289th batch is processed out of 316
# 290th batch is processed out of 316
# 291th batch is processed out of 316
# 292th batch is processed out of 316
# 293th batch is processed out of 316
# 294th batch is processed out of 316
# 295th batch is processed out of 316
# 296th batch is processed out of 316
# 297th batch is processed out of 316
# 298th batch is processed out of 316
# 299th batch is processed out of 316
# 300th batch is processed out of 316
# 301th batch is processed out of 316
# 302th batch is processed out of 316
# 303th batch is processed out of 316
# 304th batch is processed out of 316
# 305th batch is processed out of 316
# 306th batch is processed out of 316
# 307th batch is processed out of 316
# 308th batch is processed out of 316
# 309th batch is processed out of 316
# 310th batch is processed out of 316
# 311th batch is processed out of 316
# 312th batch is processed out of 316
# 313th batch is processed out of 316
# 314th batch is processed out of 316
# 315th batch is processed out of 316
# 316th batch is processed out of 316
# 0th batch is processed out of 296
# 1th batch is processed out of 296
# 2th batch is processed out of 296
# 3th batch is processed out of 296
# 4th batch is processed out of 296
# 5th batch is processed out of 296
# 6th batch is processed out of 296
# 7th batch is processed out of 296
# 8th batch is processed out of 296
# 9th batch is processed out of 296
# 10th batch is processed out of 296
# 11th batch is processed out of 296
# 12th batch is processed out of 296
# 13th batch is processed out of 296
# 14th batch is processed out of 296
# 15th batch is processed out of 296
# 16th batch is processed out of 296
# 17th batch is processed out of 296
# 18th batch is processed out of 296
# 19th batch is processed out of 296
# 20th batch is processed out of 296
# 21th batch is processed out of 296
# 22th batch is processed out of 296
# 23th batch is processed out of 296
# 24th batch is processed out of 296
# 25th batch is processed out of 296
# 26th batch is processed out of 296
# 27th batch is processed out of 296
# 28th batch is processed out of 296
# 29th batch is processed out of 296
# 30th batch is processed out of 296
# 31th batch is processed out of 296
# 32th batch is processed out of 296
# 33th batch is processed out of 296
# 34th batch is processed out of 296
# 35th batch is processed out of 296
# 36th batch is processed out of 296
# 37th batch is processed out of 296
# 38th batch is processed out of 296
# 39th batch is processed out of 296
# 40th batch is processed out of 296
# 41th batch is processed out of 296
# 42th batch is processed out of 296
# 43th batch is processed out of 296
# 44th batch is processed out of 296
# 45th batch is processed out of 296
# 46th batch is processed out of 296
# 47th batch is processed out of 296
# 48th batch is processed out of 296
# 49th batch is processed out of 296
# 50th batch is processed out of 296
# 51th batch is processed out of 296
# 52th batch is processed out of 296
# 53th batch is processed out of 296
# 54th batch is processed out of 296
# 55th batch is processed out of 296
# 56th batch is processed out of 296
# 57th batch is processed out of 296
# 58th batch is processed out of 296
# 59th batch is processed out of 296
# 60th batch is processed out of 296
# 61th batch is processed out of 296
# 62th batch is processed out of 296
# 63th batch is processed out of 296
# 64th batch is processed out of 296
# 65th batch is processed out of 296
# 66th batch is processed out of 296
# 67th batch is processed out of 296
# 68th batch is processed out of 296
# 69th batch is processed out of 296
# 70th batch is processed out of 296
# 71th batch is processed out of 296
# 72th batch is processed out of 296
# 73th batch is processed out of 296
# 74th batch is processed out of 296
# 75th batch is processed out of 296
# 76th batch is processed out of 296
# 77th batch is processed out of 296
# 78th batch is processed out of 296
# 79th batch is processed out of 296
# 80th batch is processed out of 296
# 81th batch is processed out of 296
# 82th batch is processed out of 296
# 83th batch is processed out of 296
# 84th batch is processed out of 296
# 85th batch is processed out of 296
# 86th batch is processed out of 296
# 87th batch is processed out of 296
# 88th batch is processed out of 296
# 89th batch is processed out of 296
# 90th batch is processed out of 296
# 91th batch is processed out of 296
# 92th batch is processed out of 296
# 93th batch is processed out of 296
# 94th batch is processed out of 296
# 95th batch is processed out of 296
# 96th batch is processed out of 296
# 97th batch is processed out of 296
# 98th batch is processed out of 296
# 99th batch is processed out of 296
# 100th batch is processed out of 296
# 101th batch is processed out of 296
# 102th batch is processed out of 296
# 103th batch is processed out of 296
# 104th batch is processed out of 296
# 105th batch is processed out of 296
# 106th batch is processed out of 296
# 107th batch is processed out of 296
# 108th batch is processed out of 296
# 109th batch is processed out of 296
# 110th batch is processed out of 296
# 111th batch is processed out of 296
# 112th batch is processed out of 296
# 113th batch is processed out of 296
# 114th batch is processed out of 296
# 115th batch is processed out of 296
# 116th batch is processed out of 296
# 117th batch is processed out of 296
# 118th batch is processed out of 296
# 119th batch is processed out of 296
# 120th batch is processed out of 296
# 121th batch is processed out of 296
# 122th batch is processed out of 296
# 123th batch is processed out of 296
# 124th batch is processed out of 296
# 125th batch is processed out of 296
# 126th batch is processed out of 296
# 127th batch is processed out of 296
# 128th batch is processed out of 296
# 129th batch is processed out of 296
# 130th batch is processed out of 296
# 131th batch is processed out of 296
# 132th batch is processed out of 296
# 133th batch is processed out of 296
# 134th batch is processed out of 296
# 135th batch is processed out of 296
# 136th batch is processed out of 296
# 137th batch is processed out of 296
# 138th batch is processed out of 296
# 139th batch is processed out of 296
# 140th batch is processed out of 296
# 141th batch is processed out of 296
# 142th batch is processed out of 296
# 143th batch is processed out of 296
# 144th batch is processed out of 296
# 145th batch is processed out of 296
# 146th batch is processed out of 296
# 147th batch is processed out of 296
# 148th batch is processed out of 296
# 149th batch is processed out of 296
# 150th batch is processed out of 296
# 151th batch is processed out of 296
# 152th batch is processed out of 296
# 153th batch is processed out of 296
# 154th batch is processed out of 296
# 155th batch is processed out of 296
# 156th batch is processed out of 296
# 157th batch is processed out of 296
# 158th batch is processed out of 296
# 159th batch is processed out of 296
# 160th batch is processed out of 296
# 161th batch is processed out of 296
# 162th batch is processed out of 296
# 163th batch is processed out of 296
# 164th batch is processed out of 296
# 165th batch is processed out of 296
# 166th batch is processed out of 296
# 167th batch is processed out of 296
# 168th batch is processed out of 296
# 169th batch is processed out of 296
# 170th batch is processed out of 296
# 171th batch is processed out of 296
# 172th batch is processed out of 296
# 173th batch is processed out of 296
# 174th batch is processed out of 296
# 175th batch is processed out of 296
# 176th batch is processed out of 296
# 177th batch is processed out of 296
# 178th batch is processed out of 296
# 179th batch is processed out of 296
# 180th batch is processed out of 296
# 181th batch is processed out of 296
# 182th batch is processed out of 296
# 183th batch is processed out of 296
# 184th batch is processed out of 296
# 185th batch is processed out of 296
# 186th batch is processed out of 296
# 187th batch is processed out of 296
# 188th batch is processed out of 296
# 189th batch is processed out of 296
# 190th batch is processed out of 296
# 191th batch is processed out of 296
# 192th batch is processed out of 296
# 193th batch is processed out of 296
# 194th batch is processed out of 296
# 195th batch is processed out of 296
# 196th batch is processed out of 296
# 197th batch is processed out of 296
# 198th batch is processed out of 296
# 199th batch is processed out of 296
# 200th batch is processed out of 296
# 201th batch is processed out of 296
# 202th batch is processed out of 296
# 203th batch is processed out of 296
# 204th batch is processed out of 296
# 205th batch is processed out of 296
# 206th batch is processed out of 296
# 207th batch is processed out of 296
# 208th batch is processed out of 296
# 209th batch is processed out of 296
# 210th batch is processed out of 296
# 211th batch is processed out of 296
# 212th batch is processed out of 296
# 213th batch is processed out of 296
# 214th batch is processed out of 296
# 215th batch is processed out of 296
# 216th batch is processed out of 296
# 217th batch is processed out of 296
# 218th batch is processed out of 296
# 219th batch is processed out of 296
# 220th batch is processed out of 296
# 221th batch is processed out of 296
# 222th batch is processed out of 296
# 223th batch is processed out of 296
# 224th batch is processed out of 296
# 225th batch is processed out of 296
# 226th batch is processed out of 296
# 227th batch is processed out of 296
# 228th batch is processed out of 296
# 229th batch is processed out of 296
# 230th batch is processed out of 296
# 231th batch is processed out of 296
# 232th batch is processed out of 296
# 233th batch is processed out of 296
# 234th batch is processed out of 296
# 235th batch is processed out of 296
# 236th batch is processed out of 296
# 237th batch is processed out of 296
# 238th batch is processed out of 296
# 239th batch is processed out of 296
# 240th batch is processed out of 296
# 241th batch is processed out of 296
# 242th batch is processed out of 296
# 243th batch is processed out of 296
# 244th batch is processed out of 296
# 245th batch is processed out of 296
# 246th batch is processed out of 296
# 247th batch is processed out of 296
# 248th batch is processed out of 296
# 249th batch is processed out of 296
# 250th batch is processed out of 296
# 251th batch is processed out of 296
# 252th batch is processed out of 296
# 253th batch is processed out of 296
# 254th batch is processed out of 296
# 255th batch is processed out of 296
# 256th batch is processed out of 296
# 257th batch is processed out of 296
# 258th batch is processed out of 296
# 259th batch is processed out of 296
# 260th batch is processed out of 296
# 261th batch is processed out of 296
# 262th batch is processed out of 296
# 263th batch is processed out of 296
# 264th batch is processed out of 296
# 265th batch is processed out of 296
# 266th batch is processed out of 296
# 267th batch is processed out of 296
# 268th batch is processed out of 296
# 269th batch is processed out of 296
# 270th batch is processed out of 296
# 271th batch is processed out of 296
# 272th batch is processed out of 296
# 273th batch is processed out of 296
# 274th batch is processed out of 296
# 275th batch is processed out of 296
# 276th batch is processed out of 296
# 277th batch is processed out of 296
# 278th batch is processed out of 296
# 279th batch is processed out of 296
# 280th batch is processed out of 296
# 281th batch is processed out of 296
# 282th batch is processed out of 296
# 283th batch is processed out of 296
# 284th batch is processed out of 296
# 285th batch is processed out of 296
# 286th batch is processed out of 296
# 287th batch is processed out of 296
# 288th batch is processed out of 296
# 289th batch is processed out of 296
# 290th batch is processed out of 296
# 291th batch is processed out of 296
# 292th batch is processed out of 296
# 293th batch is processed out of 296
# 294th batch is processed out of 296
# 295th batch is processed out of 296
# 296th batch is processed out of 296
# all batches processed completely

# %%
# @title Code to check alignment hidden vector with label and token on the basis of count
def check_alignment(hidden_states, all_task_alignedData):

    num_sentences = len(hidden_states[0])  # assuming all layers have same count
    print(f"Total sentences: {num_sentences}")

    for sent_idx in range(num_sentences):
        # Hidden vectors (from any one layer, e.g., layer 0)
        hidden_vecs = hidden_states[0][sent_idx]  # shape: (seq_len, hidden_dim)
        hidden_token_count = hidden_vecs.shape[0]

        # From aligned data (tokens + labels) — skip special tokens
        aligned_entries = [
            d for d in all_task_alignedData
            if d['sentence_idx'] == sent_idx and d['label'] != 'SPECIAL'
        ]
        aligned_token_count = len(aligned_entries)
        aligned_label_count = aligned_token_count  # 1 label per token

        if hidden_token_count != aligned_token_count or hidden_token_count != aligned_label_count:
            print(f"[Mismatch] Sentence {sent_idx} → Hidden: {hidden_token_count}, Tokens: {aligned_token_count}, Labels: {aligned_label_count}")
        # else:
        #     print(f"[OK] Sentence {sent_idx} → Count: {hidden_token_count}")

    print("✅ Alignment check complete.\n")
tasks=['pos','dep']
for task in tasks:
  check_alignment(train_all_task_hidden_states[task], train_all_task_alignedData[task])
# Out:
# Total sentences: 2531
# ✅ Alignment check complete.
#
# Total sentences: 2373
# ✅ Alignment check complete.

# %%
# @title Code to check the label count and token count of each sentence
def _check_label_token_count_(sentences,each_task_alignedData):
  for sent_id in range(len(sentences)):
    result = [d for d in each_task_alignedData if d.get('sentence_idx') == sent_id]
    sentence_ith= [d['token'] for d in result if 'token_idx' in d]
    sentence_ith_label= [d['label'] for d in result if 'token_idx' in d]
    # print(len(sentence_ith),len(sentence_ith_label))
    if(len(sentence_ith)!=len(sentence_ith_label)):
      print(f"mismatch at f{sent_id}")
for task in tasks:
  _check_label_token_count_(train_all_sentences[task],train_all_task_alignedData[task])

# %%
CHECKPOINT_DIR=f"/content/drive/MyDrive/SAE_outputs"
print(os.path.exists(CHECKPOINT_DIR))
# Out:
# False

# %%
# @title Code to mount drive
import os
from google.colab import drive
if( not os.path.exists('/content/drive')):
      drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# @title Function to save model's current state to drive
def save_checkpoint(layer_idx, encoder, decoder, optimizer, current_epoch,task):
    checkpoint = {
        'encoder_state_dict': encoder.state_dict(),
        'decoder_state_dict': decoder.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'epoch': current_epoch
    }
    CHECKPOINT_DIR=f"/content/drive/MyDrive/SAE_outputs/SAE_outputs_{task}"
    if(not os.path.exists(CHECKPOINT_DIR)):
          os.makedirs(CHECKPOINT_DIR, exist_ok=True)
    torch.save(checkpoint, f"{CHECKPOINT_DIR}/layer_{layer_idx}_model.pt")

# %%
# @title Function to load model's current state from drive
def load_checkpoint(layer_idx, encoder, decoder, optimizer,resume, task):
  if resume=='c':
    return 0

    checkpoint_path = f"/content/drive/MyDrive/SAE_outputs/SAE_outputs_{task}/layer_{layer_idx}_model.pt"
    print(checkpoint_path)
    if os.path.exists(checkpoint_path):
        checkpoint = torch.load(checkpoint_path)
        encoder.load_state_dict(checkpoint['encoder_state_dict'])
        decoder.load_state_dict(checkpoint['decoder_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        if(resume=='b'):
          return checkpoint.get('epoch', 0)
        else:
          return 0
    print('couldnt found the file, starting from scretch')
    return 0

# %%
# @title Function that applies topK sparsity
def _apply_top_k_sparsity(activations, k):
    top_values, top_indices = torch.topk(torch.abs(activations), k, dim=1)
    sparse_activations = torch.zeros_like(activations)
    row_idx = torch.arange(activations.size(0)).unsqueeze(1).expand(-1, k)
    sparse_activations[row_idx, top_indices] = activations[row_idx, top_indices]
    return sparse_activations

# %%
# @title Function to train Sparse autoencoder for a layer
def train_sparse_autoencoder(hidden_states, layer_idx,device, resume, task, sae_dim=2048, sparsity_coeff=0.01,
                           top_k=50, epochs=100, lr=0.001 , batch_size=131072):

        all_tokens = []
        hidden_dim =hidden_states[layer_idx][0].shape[-1]
        with torch.no_grad():
          all_tokens = torch.cat([
              batch.view(-1, hidden_dim) for batch in hidden_states[layer_idx]
          ], dim=0).to(device)





        encoder = torch.nn.Linear(hidden_dim, sae_dim, bias=True).to(device)
        decoder = torch.nn.Linear(sae_dim, hidden_dim, bias=False).to(device)
        torch.nn.init.xavier_uniform_(encoder.weight)
        torch.nn.init.xavier_uniform_(decoder.weight)
        optimizer = torch.optim.Adam(list(encoder.parameters()) + list(decoder.parameters()), lr=lr)


        start_epoch = load_checkpoint(layer_idx, encoder, decoder, optimizer,resume, task)

        dataset = torch.utils.data.TensorDataset(all_tokens)
        dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True) #splits into batches of shuffled hidden vectors while preserving the shape

        try:

            for epoch in range(start_epoch,epochs):
                total_loss = 0
                total_recon_loss = 0
                total_sparsity_loss = 0

                for batch_idx, (batch_vectors,) in enumerate(dataloader):
                    batch_vectors = batch_vectors.to(device)
                    raw_activations = encoder(batch_vectors)
                    sparse_activations = _apply_top_k_sparsity(raw_activations, top_k)
                    reconstructed = decoder(sparse_activations)
                    recon_loss = torch.nn.functional.mse_loss(reconstructed, batch_vectors)
                    sparsity_loss = torch.mean(torch.abs(sparse_activations))



                    total_loss_batch = recon_loss + sparsity_coeff * sparsity_loss
                    optimizer.zero_grad()#clears previous gradients
                    total_loss_batch.backward()#computes gradients
                    optimizer.step()#updates the weights θ=θ−η⋅gradient n is the learning rate

                    total_loss += total_loss_batch.item()
                    total_recon_loss += recon_loss.item()
                    total_sparsity_loss += sparsity_loss.item()

                if epoch % 10 == 0:
                    avg_loss = total_loss / len(dataloader)
                    avg_recon = total_recon_loss / len(dataloader)
                    avg_sparsity = total_sparsity_loss / len(dataloader)
                    print(f"Epoch {epoch}: avg-Loss={avg_loss:.4f}, Recon={avg_recon:.4f}, Sparsity={avg_sparsity:.4f} of layer{layer_idx}")

        except KeyboardInterrupt:
          print(f"\nTraining interrupted at epoch {epoch}. Saving checkpoint for layer {layer_idx}...")
          save_checkpoint(layer_idx, encoder, decoder, optimizer, epoch, task)

        save_checkpoint(layer_idx, encoder, decoder, optimizer, epoch,task)

        encoder.eval()
        decoder.eval()

# %%
# @title Function to Train the Encoder for all layers
import torch
from concurrent.futures import ThreadPoolExecutor
def _training_all_encoders_(task,hidden_states,device):
  max_parallel=1
  resume=input('retrain or resume from last epoch or start training from scratch? a/b/c ')
  # resume='c'
  def wrapped(layer_idx):
    print(f"🔧 Training SAE for layer {layer_idx} of task ", flush=True)
    return train_sparse_autoencoder(hidden_states, layer_idx, device, resume,task)

  with ThreadPoolExecutor(max_workers=max_parallel) as executor:
    executor.map(wrapped, range(num_layers))

  print(f"✅ Finished all layers")

# %%
# @title Code to execute the training of Encoder
import os, torch, pickle



tasks = ['pos','dep']


if os.path.exists("last_task.txt"):
  with open("last_task.txt", "r") as f:
    completed_tasks=f.read().strip()

else:
  completed_tasks=''
  open("last_task.txt", "w")



for each_task in tasks:
  if each_task in completed_tasks.split(' '):
    continue
  try:
    print(f"started training for task {each_task}")
    sae_models=_training_all_encoders_(each_task,train_all_task_hidden_states[each_task],device)

  except KeyboardInterrupt:
    print(f"\nTraining interrupted at task {each_task}.")
    break


  with open("last_task.txt", "a") as f:
    f.write(each_task+' ')


open("last_task.txt", "w")
# Out:
# started training for task pos
# retrain or resume from last epoch or start training from scratch? a/b/c c
# 🔧 Training SAE for layer 0 of task
# Epoch 0: avg-Loss=0.4640, Recon=0.4637, Sparsity=0.0298 of layer0
# Epoch 10: avg-Loss=0.3161, Recon=0.3158, Sparsity=0.0283 of layer0
# Epoch 20: avg-Loss=0.2421, Recon=0.2418, Sparsity=0.0339 of layer0
# Epoch 30: avg-Loss=0.1884, Recon=0.1880, Sparsity=0.0387 of layer0
# Epoch 40: avg-Loss=0.1532, Recon=0.1528, Sparsity=0.0405 of layer0
# Epoch 50: avg-Loss=0.1308, Recon=0.1304, Sparsity=0.0415 of layer0
# Epoch 60: avg-Loss=0.1156, Recon=0.1152, Sparsity=0.0421 of layer0
# Epoch 70: avg-Loss=0.1048, Recon=0.1043, Sparsity=0.0426 of layer0
# Epoch 80: avg-Loss=0.0966, Recon=0.0961, Sparsity=0.0431 of layer0
# Epoch 90: avg-Loss=0.0902, Recon=0.0898, Sparsity=0.0436 of layer0
# 🔧 Training SAE for layer 1 of task
# Epoch 0: avg-Loss=0.4905, Recon=0.4902, Sparsity=0.0305 of layer1
# Epoch 10: avg-Loss=0.3136, Recon=0.3133, Sparsity=0.0311 of layer1
# Epoch 20: avg-Loss=0.2393, Recon=0.2389, Sparsity=0.0371 of layer1
# Epoch 30: avg-Loss=0.1845, Recon=0.1840, Sparsity=0.0452 of layer1
# Epoch 40: avg-Loss=0.1502, Recon=0.1497, Sparsity=0.0502 of layer1
# Epoch 50: avg-Loss=0.1289, Recon=0.1284, Sparsity=0.0502 of layer1
# Epoch 60: avg-Loss=0.1138, Recon=0.1133, Sparsity=0.0496 of layer1
# Epoch 70: avg-Loss=0.1029, Recon=0.1024, Sparsity=0.0496 of layer1
# Epoch 80: avg-Loss=0.0947, Recon=0.0942, Sparsity=0.0499 of layer1
# Epoch 90: avg-Loss=0.0883, Recon=0.0878, Sparsity=0.0502 of layer1
# 🔧 Training SAE for layer 2 of task
# Epoch 0: avg-Loss=0.5506, Recon=0.5502, Sparsity=0.0322 of layer2
# Epoch 10: avg-Loss=0.3348, Recon=0.3344, Sparsity=0.0364 of layer2
# Epoch 20: avg-Loss=0.2477, Recon=0.2473, Sparsity=0.0488 of layer2
# Epoch 30: avg-Loss=0.1873, Recon=0.1867, Sparsity=0.0631 of layer2
# Epoch 40: avg-Loss=0.1551, Recon=0.1544, Sparsity=0.0670 of layer2
# Epoch 50: avg-Loss=0.1335, Recon=0.1329, Sparsity=0.0654 of layer2
# Epoch 60: avg-Loss=0.1179, Recon=0.1172, Sparsity=0.0649 of layer2
# Epoch 70: avg-Loss=0.1064, Recon=0.1057, Sparsity=0.0647 of layer2
# Epoch 80: avg-Loss=0.0978, Recon=0.0972, Sparsity=0.0648 of layer2
# Epoch 90: avg-Loss=0.0913, Recon=0.0906, Sparsity=0.0649 of layer2
# 🔧 Training SAE for layer 3 of task
# Epoch 0: avg-Loss=0.5825, Recon=0.5821, Sparsity=0.0321 of layer3
# Epoch 10: avg-Loss=0.3408, Recon=0.3404, Sparsity=0.0418 of layer3
# Epoch 20: avg-Loss=0.2293, Recon=0.2287, Sparsity=0.0638 of layer3
# Epoch 30: avg-Loss=0.1697, Recon=0.1689, Sparsity=0.0803 of layer3
# Epoch 40: avg-Loss=0.1384, Recon=0.1376, Sparsity=0.0819 of layer3
# Epoch 50: avg-Loss=0.1201, Recon=0.1193, Sparsity=0.0806 of layer3
# Epoch 60: avg-Loss=0.1062, Recon=0.1054, Sparsity=0.0797 of layer3
# Epoch 70: avg-Loss=0.0963, Recon=0.0956, Sparsity=0.0789 of layer3
# Epoch 80: avg-Loss=0.0890, Recon=0.0882, Sparsity=0.0786 of layer3
# Epoch 90: avg-Loss=0.0834, Recon=0.0826, Sparsity=0.0784 of layer3
# 🔧 Training SAE for layer 4 of task
# Epoch 0: avg-Loss=0.6671, Recon=0.6667, Sparsity=0.0335 of layer4
# Epoch 10: avg-Loss=0.3824, Recon=0.3819, Sparsity=0.0471 of layer4
# Epoch 20: avg-Loss=0.2442, Recon=0.2435, Sparsity=0.0752 of layer4
# Epoch 30: avg-Loss=0.1663, Recon=0.1653, Sparsity=0.1008 of layer4
# Epoch 40: avg-Loss=0.1393, Recon=0.1383, Sparsity=0.1040 of layer4
# Epoch 50: avg-Loss=0.1201, Recon=0.1191, Sparsity=0.0973 of layer4
# Epoch 60: avg-Loss=0.1069, Recon=0.1059, Sparsity=0.0968 of layer4
# Epoch 70: avg-Loss=0.0975, Recon=0.0966, Sparsity=0.0970 of layer4
# Epoch 80: avg-Loss=0.0908, Recon=0.0898, Sparsity=0.0964 of layer4
# Epoch 90: avg-Loss=0.0856, Recon=0.0846, Sparsity=0.0959 of layer4
# 🔧 Training SAE for layer 5 of task
# Epoch 0: avg-Loss=0.1510, Recon=0.1508, Sparsity=0.0168 of layer5
# Epoch 10: avg-Loss=0.0828, Recon=0.0826, Sparsity=0.0187 of layer5
# Epoch 20: avg-Loss=0.0616, Recon=0.0614, Sparsity=0.0224 of layer5
# Epoch 30: avg-Loss=0.0468, Recon=0.0465, Sparsity=0.0299 of layer5
# Epoch 40: avg-Loss=0.0386, Recon=0.0383, Sparsity=0.0315 of layer5
# Epoch 50: avg-Loss=0.0328, Recon=0.0325, Sparsity=0.0312 of layer5
# Epoch 60: avg-Loss=0.0288, Recon=0.0285, Sparsity=0.0310 of layer5
# Epoch 70: avg-Loss=0.0259, Recon=0.0256, Sparsity=0.0309 of layer5
# Epoch 80: avg-Loss=0.0237, Recon=0.0234, Sparsity=0.0308 of layer5
# Epoch 90: avg-Loss=0.0221, Recon=0.0218, Sparsity=0.0307 of layer5
# ✅ Finished all layers
# started training for task dep
# retrain or resume from last epoch or start training from scratch? a/b/c c
# 🔧 Training SAE for layer 0 of task
# Epoch 0: avg-Loss=0.4625, Recon=0.4622, Sparsity=0.0298 of layer0
# Epoch 10: avg-Loss=0.3185, Recon=0.3182, Sparsity=0.0279 of layer0
# Epoch 20: avg-Loss=0.2395, Recon=0.2392, Sparsity=0.0350 of layer0
# Epoch 30: avg-Loss=0.1829, Recon=0.1825, Sparsity=0.0394 of layer0
# Epoch 40: avg-Loss=0.1467, Recon=0.1463, Sparsity=0.0408 of layer0
# Epoch 50: avg-Loss=0.1240, Recon=0.1235, Sparsity=0.0418 of layer0
# Epoch 60: avg-Loss=0.1089, Recon=0.1085, Sparsity=0.0425 of layer0
# Epoch 70: avg-Loss=0.0981, Recon=0.0977, Sparsity=0.0430 of layer0
# Epoch 80: avg-Loss=0.0901, Recon=0.0897, Sparsity=0.0434 of layer0
# Epoch 90: avg-Loss=0.0838, Recon=0.0834, Sparsity=0.0439 of layer0
# 🔧 Training SAE for layer 1 of task
# Epoch 0: avg-Loss=0.4858, Recon=0.4855, Sparsity=0.0303 of layer1
# Epoch 10: avg-Loss=0.3154, Recon=0.3151, Sparsity=0.0305 of layer1
# Epoch 20: avg-Loss=0.2396, Recon=0.2392, Sparsity=0.0376 of layer1
# Epoch 30: avg-Loss=0.1822, Recon=0.1818, Sparsity=0.0458 of layer1
# Epoch 40: avg-Loss=0.1468, Recon=0.1463, Sparsity=0.0513 of layer1
# Epoch 50: avg-Loss=0.1250, Recon=0.1245, Sparsity=0.0511 of layer1
# Epoch 60: avg-Loss=0.1098, Recon=0.1093, Sparsity=0.0503 of layer1
# Epoch 70: avg-Loss=0.0987, Recon=0.0982, Sparsity=0.0505 of layer1
# Epoch 80: avg-Loss=0.0904, Recon=0.0899, Sparsity=0.0508 of layer1
# Epoch 90: avg-Loss=0.0839, Recon=0.0834, Sparsity=0.0510 of layer1
# 🔧 Training SAE for layer 2 of task
# Epoch 0: avg-Loss=0.5438, Recon=0.5435, Sparsity=0.0316 of layer2
# Epoch 10: avg-Loss=0.3380, Recon=0.3376, Sparsity=0.0357 of layer2
# Epoch 20: avg-Loss=0.2468, Recon=0.2463, Sparsity=0.0497 of layer2
# Epoch 30: avg-Loss=0.1844, Recon=0.1838, Sparsity=0.0634 of layer2
# Epoch 40: avg-Loss=0.1509, Recon=0.1503, Sparsity=0.0676 of layer2
# Epoch 50: avg-Loss=0.1293, Recon=0.1286, Sparsity=0.0665 of layer2
# Epoch 60: avg-Loss=0.1138, Recon=0.1131, Sparsity=0.0658 of layer2
# Epoch 70: avg-Loss=0.1026, Recon=0.1019, Sparsity=0.0656 of layer2
# Epoch 80: avg-Loss=0.0942, Recon=0.0936, Sparsity=0.0656 of layer2
# Epoch 90: avg-Loss=0.0878, Recon=0.0871, Sparsity=0.0658 of layer2
# 🔧 Training SAE for layer 3 of task
# Epoch 0: avg-Loss=0.5985, Recon=0.5981, Sparsity=0.0322 of layer3
# Epoch 10: avg-Loss=0.3520, Recon=0.3516, Sparsity=0.0418 of layer3
# Epoch 20: avg-Loss=0.2397, Recon=0.2391, Sparsity=0.0644 of layer3
# Epoch 30: avg-Loss=0.1734, Recon=0.1726, Sparsity=0.0823 of layer3
# Epoch 40: avg-Loss=0.1415, Recon=0.1407, Sparsity=0.0848 of layer3
# Epoch 50: avg-Loss=0.1233, Recon=0.1225, Sparsity=0.0826 of layer3
# Epoch 60: avg-Loss=0.1088, Recon=0.1079, Sparsity=0.0818 of layer3
# Epoch 70: avg-Loss=0.0986, Recon=0.0977, Sparsity=0.0811 of layer3
# Epoch 80: avg-Loss=0.0908, Recon=0.0900, Sparsity=0.0807 of layer3
# Epoch 90: avg-Loss=0.0848, Recon=0.0840, Sparsity=0.0807 of layer3
# 🔧 Training SAE for layer 4 of task
# Epoch 0: avg-Loss=0.6894, Recon=0.6891, Sparsity=0.0338 of layer4
# Epoch 10: avg-Loss=0.4016, Recon=0.4012, Sparsity=0.0471 of layer4
# Epoch 20: avg-Loss=0.2572, Recon=0.2565, Sparsity=0.0756 of layer4
# Epoch 30: avg-Loss=0.1712, Recon=0.1702, Sparsity=0.1021 of layer4
# Epoch 40: avg-Loss=0.1435, Recon=0.1424, Sparsity=0.1068 of layer4
# Epoch 50: avg-Loss=0.1231, Recon=0.1221, Sparsity=0.0992 of layer4
# Epoch 60: avg-Loss=0.1096, Recon=0.1086, Sparsity=0.0984 of layer4
# Epoch 70: avg-Loss=0.0999, Recon=0.0989, Sparsity=0.0986 of layer4
# Epoch 80: avg-Loss=0.0928, Recon=0.0918, Sparsity=0.0979 of layer4
# Epoch 90: avg-Loss=0.0874, Recon=0.0864, Sparsity=0.0976 of layer4
# 🔧 Training SAE for layer 5 of task
# Epoch 0: avg-Loss=0.1446, Recon=0.1445, Sparsity=0.0163 of layer5
# Epoch 10: avg-Loss=0.0798, Recon=0.0796, Sparsity=0.0183 of layer5
# Epoch 20: avg-Loss=0.0591, Recon=0.0588, Sparsity=0.0225 of layer5
# Epoch 30: avg-Loss=0.0443, Recon=0.0440, Sparsity=0.0305 of layer5
# Epoch 40: avg-Loss=0.0366, Recon=0.0363, Sparsity=0.0331 of layer5
# Epoch 50: avg-Loss=0.0310, Recon=0.0307, Sparsity=0.0320 of layer5
# Epoch 60: avg-Loss=0.0272, Recon=0.0269, Sparsity=0.0317 of layer5
# Epoch 70: avg-Loss=0.0244, Recon=0.0241, Sparsity=0.0317 of layer5
# Epoch 80: avg-Loss=0.0224, Recon=0.0221, Sparsity=0.0316 of layer5
# Epoch 90: avg-Loss=0.0208, Recon=0.0205, Sparsity=0.0316 of layer5
# ✅ Finished all layers
# <_io.TextIOWrapper name='last_task.txt' mode='w' encoding='utf-8'>

# %%
# @title Code to prepare testing dataset
test_links=[
    "https://raw.githubusercontent.com/Harry-Joseph9387/Interpreting-Layer-wise-Representations-in-LLMs-using-Sparse-Autoencoders/refs/heads/main/en_lines-ud-train.conllu",
    "https://raw.githubusercontent.com/UniversalDependencies/UD_English-GUM/master/en_gum-ud-test.conllu",
    "https://raw.githubusercontent.com/UniversalDependencies/UD_English-LinES/master/en_lines-ud-test.conllu",
    "https://raw.githubusercontent.com/UniversalDependencies/UD_English-ParTUT/master/en_partut-ud-test.conllu",
    "https://raw.githubusercontent.com/UniversalDependencies/UD_English-Atis/master/en_atis-ud-test.conllu",

    ]

max_per_label={'pos':500,'dep':500}

test_all_sentences,test_all_labels=prepare_data(test_links, max_per_label)

test_all_task_hidden_states,test_all_task_alignedData =  _extract_representations_(
        test_all_sentences,
        test_all_labels,
        tokenizer,
        num_layers,
        model,
        device
    )
# Out:
# 0th batch is processed out of 162
# 1th batch is processed out of 162
# 2th batch is processed out of 162
# 3th batch is processed out of 162
# 4th batch is processed out of 162
# 5th batch is processed out of 162
# 6th batch is processed out of 162
# 7th batch is processed out of 162
# 8th batch is processed out of 162
# 9th batch is processed out of 162
# 10th batch is processed out of 162
# 11th batch is processed out of 162
# 12th batch is processed out of 162
# 13th batch is processed out of 162
# 14th batch is processed out of 162
# 15th batch is processed out of 162
# 16th batch is processed out of 162
# 17th batch is processed out of 162
# 18th batch is processed out of 162
# 19th batch is processed out of 162
# 20th batch is processed out of 162
# 21th batch is processed out of 162
# 22th batch is processed out of 162
# 23th batch is processed out of 162
# 24th batch is processed out of 162
# 25th batch is processed out of 162
# 26th batch is processed out of 162
# 27th batch is processed out of 162
# 28th batch is processed out of 162
# 29th batch is processed out of 162
# 30th batch is processed out of 162
# 31th batch is processed out of 162
# 32th batch is processed out of 162
# 33th batch is processed out of 162
# 34th batch is processed out of 162
# 35th batch is processed out of 162
# 36th batch is processed out of 162
# 37th batch is processed out of 162
# 38th batch is processed out of 162
# 39th batch is processed out of 162
# 40th batch is processed out of 162
# 41th batch is processed out of 162
# 42th batch is processed out of 162
# 43th batch is processed out of 162
# 44th batch is processed out of 162
# 45th batch is processed out of 162
# 46th batch is processed out of 162
# 47th batch is processed out of 162
# 48th batch is processed out of 162
# 49th batch is processed out of 162
# 50th batch is processed out of 162
# 51th batch is processed out of 162
# 52th batch is processed out of 162
# 53th batch is processed out of 162
# 54th batch is processed out of 162
# 55th batch is processed out of 162
# 56th batch is processed out of 162
# 57th batch is processed out of 162
# 58th batch is processed out of 162
# 59th batch is processed out of 162
# 60th batch is processed out of 162
# 61th batch is processed out of 162
# 62th batch is processed out of 162
# 63th batch is processed out of 162
# 64th batch is processed out of 162
# 65th batch is processed out of 162
# 66th batch is processed out of 162
# 67th batch is processed out of 162
# 68th batch is processed out of 162
# 69th batch is processed out of 162
# 70th batch is processed out of 162
# 71th batch is processed out of 162
# 72th batch is processed out of 162
# 73th batch is processed out of 162
# 74th batch is processed out of 162
# 75th batch is processed out of 162
# 76th batch is processed out of 162
# 77th batch is processed out of 162
# 78th batch is processed out of 162
# 79th batch is processed out of 162
# 80th batch is processed out of 162
# 81th batch is processed out of 162
# 82th batch is processed out of 162
# 83th batch is processed out of 162
# 84th batch is processed out of 162
# 85th batch is processed out of 162
# 86th batch is processed out of 162
# 87th batch is processed out of 162
# 88th batch is processed out of 162
# 89th batch is processed out of 162
# 90th batch is processed out of 162
# 91th batch is processed out of 162
# 92th batch is processed out of 162
# 93th batch is processed out of 162
# 94th batch is processed out of 162
# 95th batch is processed out of 162
# 96th batch is processed out of 162
# 97th batch is processed out of 162
# 98th batch is processed out of 162
# 99th batch is processed out of 162
# 100th batch is processed out of 162
# 101th batch is processed out of 162
# 102th batch is processed out of 162
# 103th batch is processed out of 162
# 104th batch is processed out of 162
# 105th batch is processed out of 162
# 106th batch is processed out of 162
# 107th batch is processed out of 162
# 108th batch is processed out of 162
# 109th batch is processed out of 162
# 110th batch is processed out of 162
# 111th batch is processed out of 162
# 112th batch is processed out of 162
# 113th batch is processed out of 162
# 114th batch is processed out of 162
# 115th batch is processed out of 162
# 116th batch is processed out of 162
# 117th batch is processed out of 162
# 118th batch is processed out of 162
# 119th batch is processed out of 162
# 120th batch is processed out of 162
# 121th batch is processed out of 162
# 122th batch is processed out of 162
# 123th batch is processed out of 162
# 124th batch is processed out of 162
# 125th batch is processed out of 162
# 126th batch is processed out of 162
# 127th batch is processed out of 162
# 128th batch is processed out of 162
# 129th batch is processed out of 162
# 130th batch is processed out of 162
# 131th batch is processed out of 162
# 132th batch is processed out of 162
# 133th batch is processed out of 162
# 134th batch is processed out of 162
# 135th batch is processed out of 162
# 136th batch is processed out of 162
# 137th batch is processed out of 162
# 138th batch is processed out of 162
# 139th batch is processed out of 162
# 140th batch is processed out of 162
# 141th batch is processed out of 162
# 142th batch is processed out of 162
# 143th batch is processed out of 162
# 144th batch is processed out of 162
# 145th batch is processed out of 162
# 146th batch is processed out of 162
# 147th batch is processed out of 162
# 148th batch is processed out of 162
# 149th batch is processed out of 162
# 150th batch is processed out of 162
# 151th batch is processed out of 162
# 152th batch is processed out of 162
# 153th batch is processed out of 162
# 154th batch is processed out of 162
# 155th batch is processed out of 162
# 156th batch is processed out of 162
# 157th batch is processed out of 162
# 158th batch is processed out of 162
# 159th batch is processed out of 162
# 160th batch is processed out of 162
# 161th batch is processed out of 162
# 162th batch is processed out of 162
# 0th batch is processed out of 135
# 1th batch is processed out of 135
# 2th batch is processed out of 135
# 3th batch is processed out of 135
# 4th batch is processed out of 135
# 5th batch is processed out of 135
# 6th batch is processed out of 135
# 7th batch is processed out of 135
# 8th batch is processed out of 135
# 9th batch is processed out of 135
# 10th batch is processed out of 135
# 11th batch is processed out of 135
# 12th batch is processed out of 135
# 13th batch is processed out of 135
# 14th batch is processed out of 135
# 15th batch is processed out of 135
# 16th batch is processed out of 135
# 17th batch is processed out of 135
# 18th batch is processed out of 135
# 19th batch is processed out of 135
# 20th batch is processed out of 135
# 21th batch is processed out of 135
# 22th batch is processed out of 135
# 23th batch is processed out of 135
# 24th batch is processed out of 135
# 25th batch is processed out of 135
# 26th batch is processed out of 135
# 27th batch is processed out of 135
# 28th batch is processed out of 135
# 29th batch is processed out of 135
# 30th batch is processed out of 135
# 31th batch is processed out of 135
# 32th batch is processed out of 135
# 33th batch is processed out of 135
# 34th batch is processed out of 135
# 35th batch is processed out of 135
# 36th batch is processed out of 135
# 37th batch is processed out of 135
# 38th batch is processed out of 135
# 39th batch is processed out of 135
# 40th batch is processed out of 135
# 41th batch is processed out of 135
# 42th batch is processed out of 135
# 43th batch is processed out of 135
# 44th batch is processed out of 135
# 45th batch is processed out of 135
# 46th batch is processed out of 135
# 47th batch is processed out of 135
# 48th batch is processed out of 135
# 49th batch is processed out of 135
# 50th batch is processed out of 135
# 51th batch is processed out of 135
# 52th batch is processed out of 135
# 53th batch is processed out of 135
# 54th batch is processed out of 135
# 55th batch is processed out of 135
# 56th batch is processed out of 135
# 57th batch is processed out of 135
# 58th batch is processed out of 135
# 59th batch is processed out of 135
# 60th batch is processed out of 135
# 61th batch is processed out of 135
# 62th batch is processed out of 135
# 63th batch is processed out of 135
# 64th batch is processed out of 135
# 65th batch is processed out of 135
# 66th batch is processed out of 135
# 67th batch is processed out of 135
# 68th batch is processed out of 135
# 69th batch is processed out of 135
# 70th batch is processed out of 135
# 71th batch is processed out of 135
# 72th batch is processed out of 135
# 73th batch is processed out of 135
# 74th batch is processed out of 135
# 75th batch is processed out of 135
# 76th batch is processed out of 135
# 77th batch is processed out of 135
# 78th batch is processed out of 135
# 79th batch is processed out of 135
# 80th batch is processed out of 135
# 81th batch is processed out of 135
# 82th batch is processed out of 135
# 83th batch is processed out of 135
# 84th batch is processed out of 135
# 85th batch is processed out of 135
# 86th batch is processed out of 135
# 87th batch is processed out of 135
# 88th batch is processed out of 135
# 89th batch is processed out of 135
# 90th batch is processed out of 135
# 91th batch is processed out of 135
# 92th batch is processed out of 135
# 93th batch is processed out of 135
# 94th batch is processed out of 135
# 95th batch is processed out of 135
# 96th batch is processed out of 135
# 97th batch is processed out of 135
# 98th batch is processed out of 135
# 99th batch is processed out of 135
# 100th batch is processed out of 135
# 101th batch is processed out of 135
# 102th batch is processed out of 135
# 103th batch is processed out of 135
# 104th batch is processed out of 135
# 105th batch is processed out of 135
# 106th batch is processed out of 135
# 107th batch is processed out of 135
# 108th batch is processed out of 135
# 109th batch is processed out of 135
# 110th batch is processed out of 135
# 111th batch is processed out of 135
# 112th batch is processed out of 135
# 113th batch is processed out of 135
# 114th batch is processed out of 135
# 115th batch is processed out of 135
# 116th batch is processed out of 135
# 117th batch is processed out of 135
# 118th batch is processed out of 135
# 119th batch is processed out of 135
# 120th batch is processed out of 135
# 121th batch is processed out of 135
# 122th batch is processed out of 135
# 123th batch is processed out of 135
# 124th batch is processed out of 135
# 125th batch is processed out of 135
# 126th batch is processed out of 135
# 127th batch is processed out of 135
# 128th batch is processed out of 135
# 129th batch is processed out of 135
# 130th batch is processed out of 135
# 131th batch is processed out of 135
# 132th batch is processed out of 135
# 133th batch is processed out of 135
# 134th batch is processed out of 135
# 135th batch is processed out of 135
# all batches processed completely

# %%
label_freqs = count_label_frequencies_per_task(test_all_labels)

for task, counter in label_freqs.items():
    print(f"\nLabel frequencies for task '{task}':")
    for label, count in counter.most_common():
        print(f"  {label}: {count}")
# Out:
# Label frequencies for task 'pos':
#   VERB: 500
#   PROPN: 500
#   NOUN: 500
#   ADJ: 500
#   ADV: 500
#   GRAMMAR: 242
#   NUM: 30
#
# Label frequencies for task 'dep':
#   ROOT: 500
#   ARGUMENT: 500
#   FUNC: 500
#   MODIFIER: 500
#   COORD: 500
#   CLAUSE_LINK: 500
#   DISCOURSE: 76
#   OTHER: 37

# %%
for task in ['pos','dep']:
  _check_label_token_count_(test_all_sentences[task],test_all_task_alignedData[task])

# %%
for task in ['pos','dep']:
  check_alignment(test_all_task_hidden_states[task], test_all_task_alignedData[task])
# Out:
# Total sentences: 1302
# ✅ Alignment check complete.
#
# Total sentences: 1087
# ✅ Alignment check complete.

# %%
# @title Function to load the trained sae models
def _load_trained_sae_models_(task):
  models={}
  base_dir=f"/content/drive/MyDrive/SAE_outputs/SAE_outputs_{task}"
  for layer_idx in range(num_layers):
    model_path = os.path.join(base_dir, f"layer_{layer_idx}_model.pt")
    checkpoint = torch.load(model_path, map_location=device)
    hidden_dim = checkpoint['encoder_state_dict']['weight'].shape[1]
    sae_dim = checkpoint['encoder_state_dict']['weight'].shape[0]

    encoder = torch.nn.Linear(hidden_dim, sae_dim, bias=True).to(device)
    encoder.load_state_dict(checkpoint['encoder_state_dict'])


    models[layer_idx] = {
        'encoder': encoder,
        'layer_idx': layer_idx
    }
  return models

# %%
# @title Function to determine right label for a token and makes changes accordingly to its related variables
from sklearn.feature_selection import mutual_info_classif
from collections import defaultdict
import numpy as np
import torch

def filter_by_mutual_information(all_features, aligned_data, hidden_states):
    """
    Filters token-label pairs using mutual information and returns updated
    activation vectors, aligned data, and hidden states.

    Args:
        all_features (Tensor): SAE activation vectors (N, hidden_dim)
        aligned_data (List[Dict]): List of aligned metadata (token, label, sentence_idx, etc.)
        hidden_states (Dict[int, List[Tensor]]): Hidden states for each layer

    Returns:
        Tuple: (filtered_all_features, filtered_aligned_data, filtered_hidden_states)
    """
    # Group vectors and labels by token
    token_vecs = defaultdict(list)
    token_labels = defaultdict(list)
    token_indices = defaultdict(list)

    for idx, (vec, entry) in enumerate(zip(all_features, aligned_data)):
        token = entry['token']
        label = entry['label']
        token_vecs[token].append(vec.numpy())
        token_labels[token].append(label)
        token_indices[token].append(idx)

    retained_indices = set()

    for token in token_vecs:
        X = np.stack(token_vecs[token])
        y = token_labels[token]

        unique_labels = set(y)
        if len(unique_labels) == 1:
            retained_indices.update(token_indices[token])
        else:
            try:
                mi = mutual_info_classif(X, y, discrete_features=False)
                label_scores = defaultdict(float)

                for i, label in enumerate(y):
                    label_scores[label] += np.sum(mi)

                best_label = max(label_scores, key=label_scores.get)

                for i, label in enumerate(y):
                    if label == best_label:
                        retained_indices.add(token_indices[token][i])
            except:
                continue

    # Apply filtering to aligned_data and all_features
    filtered_aligned_data = [aligned_data[i] for i in sorted(retained_indices)]
    filtered_all_features = torch.stack([all_features[i] for i in sorted(retained_indices)])

    # Rebuild hidden_states
    layer_count = len(hidden_states)
    filtered_hidden_states = {layer: [] for layer in range(layer_count)}
    grouped_by_sent = defaultdict(lambda: defaultdict(list))

    for i, entry in enumerate(filtered_aligned_data):
        sent_idx = entry['sentence_idx']
        token_idx = entry['token_idx']
        for layer in range(layer_count):
            grouped_by_sent[sent_idx][layer].append((token_idx, all_features[i]))

    for layer in range(layer_count):
        for sent_idx in range(len(hidden_states[layer])):
            sent_len = hidden_states[layer][sent_idx].shape[0]
            new_vecs = [vec for _, vec in sorted(grouped_by_sent[sent_idx][layer], key=lambda x: x[0])]
            filtered_tensor = torch.stack(new_vecs) if new_vecs else torch.empty((0, hidden_states[layer][sent_idx].shape[1]))
            filtered_hidden_states[layer].append(filtered_tensor)

    return filtered_all_features, filtered_aligned_data, filtered_hidden_states

# %%
# @title Function to interpret strongly activated features for a layer
def _find_interpretable_features(all_features, aligned_data, top_n=10):

        interpretable_features = []
        num_features = all_features.shape[1]

        for feature_idx in range(num_features):
            feature_activations = all_features[:, feature_idx]
            threshold = torch.quantile(feature_activations, 0.90)
            strong_positions = torch.where(feature_activations > threshold)[0]

            if len(strong_positions) < 5:
                continue

            labels_for_feature = []
            for pos in strong_positions:
                labels_for_feature.append(aligned_data[pos.item()]['label']) #aligned data is a list of dictionary representing each token , each token data is just appended

            if labels_for_feature:
                from collections import Counter
                label_counts = Counter(labels_for_feature)
                most_common_count = label_counts.most_common(1)[0][1]
                consistency = most_common_count / len(labels_for_feature)

                interpretable_features.append({
                    'feature_idx': feature_idx,
                    'consistency': consistency,
                    'dominant_label': label_counts.most_common(1)[0][0],
                    'activation_count': len(strong_positions),
                    'label_distribution': dict(label_counts.most_common(5))
                })

        '''
            interpretable_features = [
        {'feature_idx': 5, 'consistency': 0.87},
        {'feature_idx': 2, 'consistency': 0.93},
        {'feature_idx': 7, 'consistency': 0.76}
        ]

        '''

        interpretable_features.sort(key=lambda x: x['consistency'], reverse=True)
        return interpretable_features[:top_n]

# %%
# @title Function to test a Trained encoder
def test_sparse_autoencoder(sae_model, hidden_states, aligned_data,device,layer_idx,top_k=50):

        layer_idx = sae_model['layer_idx']
        encoder = sae_model['encoder']
        top_k = top_k


        all_features = []


        encoder.eval()

        with torch.no_grad():
            for each_batch in hidden_states[layer_idx]:
                seq_len, hidden_dim = each_batch.shape
                each_batch_combined_tokens = each_batch.view(-1, hidden_dim).to(device)
                raw_activations = encoder(each_batch_combined_tokens)
                sparse_features = _apply_top_k_sparsity(raw_activations, top_k)
                all_features.append(sparse_features.cpu())

        all_features = torch.cat(all_features, dim=0)

        all_features,aligned_data,hidden_states=filter_by_mutual_information(all_features, aligned_data,hidden_states)


        interpretable_features =_find_interpretable_features(all_features, aligned_data, top_n=10)


        return {
            'layer_idx': layer_idx,
            'features': all_features,
            'interpretable_features': interpretable_features,

        }

# %%
# @title Function to test Trained encoders from all layers
from concurrent.futures import ThreadPoolExecutor

def _testing_all_encoders_(sae_models,hidden_states,aligned_data,device,task):
  max_parallel=3
  each_task_sae_results = {}

  def wrapped(layer_idx):
    print(f" Testing SAE for layer {layer_idx} of task '{task}'", flush=True)
    return test_sparse_autoencoder(sae_models[layer_idx], hidden_states, aligned_data,device,layer_idx)

  with ThreadPoolExecutor(max_workers=max_parallel) as executor:
    futures = executor.map(wrapped, range(num_layers))

    for layer_idx, result in enumerate(futures):
      each_task_sae_results[layer_idx] = result
  print(f" Finished testing all layers for task '{task}'")
  return each_task_sae_results

# %%
# @title Code to execute the testing phase
tasks = ['pos','dep']


sae_models_results={}
if os.path.exists("last_task.txt"):
  with open("last_task.txt", "r") as f:
    completed_tasks=f.read().strip()

else:
  completed_tasks=''
  open("last_task.txt", "w")



for each_task in tasks:
  if each_task in completed_tasks.split(' '):
    continue

  try:
    print(f"started testing for task {each_task}")

    sae_models=_load_trained_sae_models_(each_task)
    sae_models_results[each_task]=_testing_all_encoders_(sae_models,test_all_task_hidden_states[each_task],test_all_task_alignedData[each_task],device,each_task)

  except KeyboardInterrupt:
          print(f"\nTraining interrupted at task {each_task}.")
          break
  with open("last_task.txt", "a") as f:
    f.write(each_task+' ')
# Out:
# started testing for task pos
#  Testing SAE for layer 0 of task 'pos'
#  Testing SAE for layer 1 of task 'pos'
#  Testing SAE for layer 2 of task 'pos'
#  Testing SAE for layer 3 of task 'pos'
#  Testing SAE for layer 4 of task 'pos'
#  Testing SAE for layer 5 of task 'pos'
#  Finished testing all layers for task 'pos'
# started testing for task dep
#  Testing SAE for layer 0 of task 'dep'
#  Testing SAE for layer 1 of task 'dep'
#  Testing SAE for layer 2 of task 'dep'
#  Testing SAE for layer 3 of task 'dep'
#  Testing SAE for layer 4 of task 'dep'
#  Testing SAE for layer 5 of task 'dep'
#  Finished testing all layers for task 'dep'

# %%
# @title Code to display the interpretation of each layer
from collections import defaultdict, Counter

def summarize_labels_per_task(sae_output):
    print("🔍 PER-TASK SAE LAYER SUMMARY\n")

    for task, task_data in sae_output.items():
        print(f"📘 Task: {task}")
        for layer_idx, layer_data in task_data.items():
            label_counts = Counter([f['dominant_label'] for f in layer_data['interpretable_features']])
            top_labels = label_counts.most_common(3)

            print(f"  Layer {layer_idx}:")
            print(f"   - Dominant label     : {top_labels[0][0]} ({top_labels[0][1]} features)")
            if len(top_labels) > 1:
                print("   - Other strong labels:")
                for label, count in top_labels[1:]:
                    print(f"       - {label}: {count}")
            else:
                print("   - No other strong label")

            total_feats = sum(label_counts.values())
            print(f"  - Total features     : {total_feats}")
            print()
        print("-" * 40)


def summarize_labels_per_layer_across_tasks(sae_output):
    layer_label_map = defaultdict(list)  # {layer_idx: [dominant_labels from all tasks]}

    for task_data in sae_output.values():
        for layer_idx, layer_data in task_data.items():
            for feat in layer_data['interpretable_features']:
                label = feat['dominant_label']
                layer_label_map[layer_idx].append(label)

    print("🌐 GLOBAL SAE LAYER SUMMARY (All Tasks)\n")
    for layer_idx in sorted(layer_label_map.keys()):
        label_counts = Counter(layer_label_map[layer_idx])
        top_labels = label_counts.most_common(3)

        print(f"  Layer {layer_idx}:")
        print(f"   - Dominant label     : {top_labels[0][0]} ({top_labels[0][1]} features)")
        if len(top_labels) > 1:
            print("   - Other strong labels:")
            for label, count in top_labels[1:]:
                print(f"       - {label}: {count}")
        else:
            print("   - No other strong label")

        total_feats = sum(label_counts.values())
        print(f"  - Total features     : {total_feats}")
        print()
# Run summaries after testing
summarize_labels_per_task(sae_models_results)
summarize_labels_per_layer_across_tasks(sae_models_results)
# Out:
# 🔍 PER-TASK SAE LAYER SUMMARY
#
# 📘 Task: pos
#   Layer 0:
#    - Dominant label     : ADV (7 features)
#    - Other strong labels:
#        - PROPN: 3
#   - Total features     : 10
#
#   Layer 1:
#    - Dominant label     : ADV (5 features)
#    - Other strong labels:
#        - PROPN: 2
#        - ADJ: 1
#   - Total features     : 10
#
#   Layer 2:
#    - Dominant label     : PROPN (5 features)
#    - Other strong labels:
#        - ADV: 3
#        - GRAMMAR: 1
#   - Total features     : 10
#
#   Layer 3:
#    - Dominant label     : PROPN (6 features)
#    - Other strong labels:
#        - ADV: 3
#        - VERB: 1
#   - Total features     : 10
#
#   Layer 4:
#    - Dominant label     : PROPN (10 features)
#    - No other strong label
#   - Total features     : 10
#
#   Layer 5:
#    - Dominant label     : PROPN (6 features)
#    - Other strong labels:
#        - ADV: 3
#        - NOUN: 1
#   - Total features     : 10
#
# ----------------------------------------
# 📘 Task: dep
#   Layer 0:
#    - Dominant label     : FUNC (3 features)
#    - Other strong labels:
#        - COORD: 3
#        - CLAUSE_LINK: 2
#   - Total features     : 10
#
#   Layer 1:
#    - Dominant label     : FUNC (4 features)
#    - Other strong labels:
#        - CLAUSE_LINK: 3
#        - OTHER: 2
#   - Total features     : 10
#
#   Layer 2:
#    - Dominant label     : FUNC (8 features)
#    - Other strong labels:
#        - OTHER: 1
#        - COORD: 1
#   - Total features     : 10
#
#   Layer 3:
#    - Dominant label     : FUNC (8 features)
#    - Other strong labels:
#        - ROOT: 1
#        - ARGUMENT: 1
#   - Total features     : 10
#
#   Layer 4:
#    - Dominant label     : FUNC (8 features)
#    - Other strong labels:
#        - OTHER: 2
#   - Total features     : 10
#
#   Layer 5:
#    - Dominant label     : FUNC (8 features)
#    - Other strong labels:
#        - COORD: 1
#        - ROOT: 1
#   - Total features     : 10
#
# ----------------------------------------
# 🌐 GLOBAL SAE LAYER SUMMARY (All Tasks)
#
#   Layer 0:
#    - Dominant label     : ADV (7 features)
#    - Other strong labels:
#        - PROPN: 3
#        - FUNC: 3
#   - Total features     : 20
#
#   Layer 1:
#    - Dominant label     : ADV (5 features)
#    - Other strong labels:
#        - FUNC: 4
#        - CLAUSE_LINK: 3
#   - Total features     : 20
#
#   Layer 2:
#    - Dominant label     : FUNC (8 features)
#    - Other strong labels:
#        - PROPN: 5
#        - ADV: 3
#   - Total features     : 20
#
#   Layer 3:
#    - Dominant label     : FUNC (8 features)
#    - Other strong labels:
#        - PROPN: 6
#        - ADV: 3
#   - Total features     : 20
#
#   Layer 4:
#    - Dominant label     : PROPN (10 features)
#    - Other strong labels:
#        - FUNC: 8
#        - OTHER: 2
#   - Total features     : 20
#
#   Layer 5:
#    - Dominant label     : FUNC (8 features)
#    - Other strong labels:
#        - PROPN: 6
#        - ADV: 3
#   - Total features     : 20
