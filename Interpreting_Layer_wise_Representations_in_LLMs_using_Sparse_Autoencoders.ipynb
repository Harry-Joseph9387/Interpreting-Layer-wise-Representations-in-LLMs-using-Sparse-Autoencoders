# %%
# @title Installing  conllu
# !pip install conllu
# Out:
# Collecting conllu
#   Downloading conllu-6.0.0-py3-none-any.whl.metadata (21 kB)
# Downloading conllu-6.0.0-py3-none-any.whl (16 kB)
# Installing collected packages: conllu
# Successfully installed conllu-6.0.0

# %%
# @title importing required modules
import torch
import numpy as np
import pandas as pd
from transformers import AutoTokenizer, AutoModel
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score
import json
import os

# %%
# @title Function to input from user about model
def get_user_model_choice():
        print("Available model options:")
        models = {
            '1': 'distilbert-base-uncased',
            '2': 'bert-base-uncased',
            '3': 'gpt2',
            '4': 'microsoft/DialoGPT-medium',
            '5': 'google/electra-small-discriminator',
            '6': 'facebook/opt-350m',
            '7': 'custom'
        }

        for key, value in models.items():
            print(f"{key}: {value}")

        choice = input("Enter your choice (1-7): ").strip()

        if choice == '7':
            model_name = input("Enter custom model name from HuggingFace: ").strip()
            return model_name
        elif choice in models:
            return models[choice]
        else:
            print("Invalid choice, using default DistilBERT")
            return 'distilbert-base-uncased'

# %%
# @title Function to find the attribute of getting no. of layers
def _get_num_layers(model):
        #has_attr or has attribute checks whether this attribute is available in the model or not4
        if hasattr(model.config, 'n_layers'):
            return model.config.n_layers
        elif hasattr(model.config, 'num_hidden_layers'):
            return model.config.num_hidden_layers
        elif hasattr(model.config, 'n_layer'):
            return model.config.n_layer
        else:
            print("Not able to find")

# %%
# @title Model initialization Phase
model_name = get_user_model_choice()
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name, output_hidden_states=False,attn_implementation="eager", output_attentions=True)
model.eval()
label_encoder = LabelEncoder()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)
num_layers = _get_num_layers(model)
if tokenizer.pad_token is None:
  tokenizer.pad_token = tokenizer.eos_token
# Out:
# Available model options:
# 1: distilbert-base-uncased
# 2: bert-base-uncased
# 3: gpt2
# 4: microsoft/DialoGPT-medium
# 5: google/electra-small-discriminator
# 6: facebook/opt-350m
# 7: custom
# Enter your choice (1-7): 1
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]

# %%
# @title Function to Prepare dataset
def prepare_data(test=None):
    import requests
    from io import StringIO
    from conllu import parse_incr

    # Load data
    if(not test):
      conllu_url = "https://raw.githubusercontent.com/Harry-Joseph9387/Interpreting-Layer-wise-Representations-in-LLMs-using-Sparse-Autoencoders/refs/heads/main/en_lines-ud-train.conllu"
    else:
      conllu_url = "https://raw.githubusercontent.com/Harry-Joseph9387/Interpreting-Layer-wise-Representations-in-LLMs-using-Sparse-Autoencoders/refs/heads/main/en_ewt-ud-train.conllu"

    response = requests.get(conllu_url)
    file_content = StringIO(response.text)

    sentences = []
    pos_labels = []
    dep_labels = []
    position_labels = []

    for tokenlist in parse_incr(file_content):
        if not tokenlist:
            continue

        tokens = []
        pos = []
        dep = []

        for token in tokenlist:
            if isinstance(token["id"], int) and token["form"] is not None:
                tokens.append(token["form"])
                pos.append(token["upos"])
                dep.append(token["deprel"])

        if tokens:
            sentences.append(" ".join(tokens))
            pos_labels.append(pos)
            dep_labels.append(dep)
            position_labels.append(list(range(len(tokens))))

    return sentences, {'pos': pos_labels, 'dep': dep_labels, 'position': position_labels}

# %%
sentences,labels_dict=prepare_data()

# %%
# @title Function to align tokens with labels
def _align_tokens_with_labels(sentences, labels, all_tokens, task_type):
    aligned_data = []

    for sent_idx, (sentence, original_labels, tokens) in enumerate(zip(sentences, labels, all_tokens)):
        # Split sentence into words
        original_words = sentence.split()

        # Create mapping from token positions to labels
        word_idx = 0

        # Process ALL tokens (including special tokens)
        for token_idx, token in enumerate(tokens):

            # Handle special tokens - assign a special label or skip labeling
            if token in ['[CLS]', '[SEP]', '[PAD]', '<s>', '</s>', '<pad>']:
                aligned_data.append({
                    'sentence_idx': sent_idx,
                    'token_idx': token_idx,  # Use 0-based indexing
                    'label': 'SPECIAL',  # Or use None if you want to skip
                    'task': task_type,
                    'token': token
                })
                continue

            # Handle subword tokens (BERT-style)
            if token.startswith('##'):
                # Use the same label as the previous token (if it exists and is from same sentence)
                if aligned_data and aligned_data[-1]['sentence_idx'] == sent_idx:
                    label = aligned_data[-1]['label']
                else:
                    # Fallback: try to get label from current word_idx
                    if word_idx < len(original_labels):
                        label = original_labels[word_idx]
                    else:
                        label = 'O'  # Default label
            else:
                # Regular token - get label from original_labels
                if word_idx < len(original_labels):
                    label = original_labels[word_idx]
                    word_idx += 1
                else:
                    # Out of bounds - might be due to tokenization differences
                    label = 'O'  # Default label

            aligned_data.append({
                'sentence_idx': sent_idx,
                'token_idx': token_idx,  # Use 0-based indexing consistently
                'label': label,
                'task': task_type,
                'token': token  # Store token for debugging
            })

    print(f"Aligned data size: {len(aligned_data)}")
    return aligned_data

# %%
# @title Function to extract hidden representations from model
def _extract_representations(sentences, labels_dict,tokenizer,num_layers,model,device,test=None):
        all_hidden_states = {i: [] for i in range(num_layers )}
        '''
            {0: [],1: [], 2: [], 3: [], 4: [], 5: []}
            	dict_id represents the nth layer
            	its value is a list containing hidden vector of that layer of every batch
            	each batch is represented as tensor(batchsize,seq_len,hidden_dim) where batchsize is no. of sentences
        '''
        all_tokens = []
        batch_size = 8

        for i in range(0, len(sentences), batch_size):
            batch = sentences[i:i+batch_size]
            if(1):
                encoded = tokenizer(batch, padding=True, truncation=True,
                                       max_length=128, return_tensors='pt')

                with torch.no_grad():
                    outputs = model(input_ids=encoded['input_ids'].to(device),attention_mask=encoded['attention_mask'].to(device), output_hidden_states=True )

                    if hasattr(outputs, 'hidden_states'):
                        hidden_states = outputs.hidden_states
                    else:
                        hidden_states = [outputs.last_hidden_state]
                    '''
                        all_hidden_states is typically a dictionary of tensors with key as nth layer, where
                        each tensor corresponds to the hidden state of a specific layer
                    '''

                    print(f"{i/batch_size}th batch is processed out of {len(sentences)/batch_size}")
                    for layer_idx, hidden in enumerate(hidden_states):
                        '''
                            first index stores the emmbedding output
                            setting hidden vector of layer1 to dict_id of 0 and  same for others like layer2 to id 1
                        '''
                        if(layer_idx!=0):
                            all_hidden_states[layer_idx-1].append(hidden.cpu())

                    #doing this conversion as a formality to train with actual human interpretable labels
                    for sent_ids in encoded['input_ids']:
                        tokens = tokenizer.convert_ids_to_tokens(sent_ids)
                        all_tokens.append(tokens)
        print("all batches processed completely")

        # Initialize aligned data for all tasks
        all_task_alignedData = {}
        for task_type in ['pos', 'dep', 'position']:
            all_task_alignedData[task_type] = []

        # Process alignment batch by batch to maintain correct correspondence
        for i in range(0, len(sentences), batch_size):
            batch_sentences = sentences[i:i+batch_size]
            batch_tokens = all_tokens[i:i+batch_size]

            for task_type in ['pos', 'dep', 'position']:
                batch_labels = labels_dict[task_type][i:i+batch_size]
                batch_aligned_data = _align_tokens_with_labels(batch_sentences, batch_labels, batch_tokens, task_type)
                all_task_alignedData[task_type].extend(batch_aligned_data)

        return all_hidden_states,all_task_alignedData

# %%
all_hidden_states,all_task_alignedData=_extract_representations(sentences, labels_dict,tokenizer,num_layers,model,device)
# Out:
# 0.0th batch is processed out of 432.125
# 1.0th batch is processed out of 432.125
# 2.0th batch is processed out of 432.125
# 3.0th batch is processed out of 432.125
# 4.0th batch is processed out of 432.125
# 5.0th batch is processed out of 432.125
# 6.0th batch is processed out of 432.125
# 7.0th batch is processed out of 432.125
# 8.0th batch is processed out of 432.125
# 9.0th batch is processed out of 432.125
# 10.0th batch is processed out of 432.125
# 11.0th batch is processed out of 432.125
# 12.0th batch is processed out of 432.125
# 13.0th batch is processed out of 432.125
# 14.0th batch is processed out of 432.125
# 15.0th batch is processed out of 432.125
# 16.0th batch is processed out of 432.125
# 17.0th batch is processed out of 432.125
# 18.0th batch is processed out of 432.125
# 19.0th batch is processed out of 432.125
# 20.0th batch is processed out of 432.125
# 21.0th batch is processed out of 432.125
# 22.0th batch is processed out of 432.125
# 23.0th batch is processed out of 432.125
# 24.0th batch is processed out of 432.125
# 25.0th batch is processed out of 432.125
# 26.0th batch is processed out of 432.125
# 27.0th batch is processed out of 432.125
# 28.0th batch is processed out of 432.125
# 29.0th batch is processed out of 432.125
# 30.0th batch is processed out of 432.125
# 31.0th batch is processed out of 432.125
# 32.0th batch is processed out of 432.125
# 33.0th batch is processed out of 432.125
# 34.0th batch is processed out of 432.125
# 35.0th batch is processed out of 432.125
# 36.0th batch is processed out of 432.125
# 37.0th batch is processed out of 432.125
# 38.0th batch is processed out of 432.125
# 39.0th batch is processed out of 432.125
# 40.0th batch is processed out of 432.125
# 41.0th batch is processed out of 432.125
# 42.0th batch is processed out of 432.125
# 43.0th batch is processed out of 432.125
# 44.0th batch is processed out of 432.125
# 45.0th batch is processed out of 432.125
# 46.0th batch is processed out of 432.125
# 47.0th batch is processed out of 432.125
# 48.0th batch is processed out of 432.125
# 49.0th batch is processed out of 432.125
# 50.0th batch is processed out of 432.125
# 51.0th batch is processed out of 432.125
# 52.0th batch is processed out of 432.125
# 53.0th batch is processed out of 432.125
# 54.0th batch is processed out of 432.125
# 55.0th batch is processed out of 432.125
# 56.0th batch is processed out of 432.125
# 57.0th batch is processed out of 432.125
# 58.0th batch is processed out of 432.125
# 59.0th batch is processed out of 432.125
# 60.0th batch is processed out of 432.125
# 61.0th batch is processed out of 432.125
# 62.0th batch is processed out of 432.125
# 63.0th batch is processed out of 432.125
# 64.0th batch is processed out of 432.125
# 65.0th batch is processed out of 432.125
# 66.0th batch is processed out of 432.125
# 67.0th batch is processed out of 432.125
# 68.0th batch is processed out of 432.125
# 69.0th batch is processed out of 432.125
# 70.0th batch is processed out of 432.125
# 71.0th batch is processed out of 432.125
# 72.0th batch is processed out of 432.125
# 73.0th batch is processed out of 432.125
# 74.0th batch is processed out of 432.125
# 75.0th batch is processed out of 432.125
# 76.0th batch is processed out of 432.125
# 77.0th batch is processed out of 432.125
# 78.0th batch is processed out of 432.125
# 79.0th batch is processed out of 432.125
# 80.0th batch is processed out of 432.125
# 81.0th batch is processed out of 432.125
# 82.0th batch is processed out of 432.125
# 83.0th batch is processed out of 432.125
# 84.0th batch is processed out of 432.125
# 85.0th batch is processed out of 432.125
# 86.0th batch is processed out of 432.125
# 87.0th batch is processed out of 432.125
# 88.0th batch is processed out of 432.125
# 89.0th batch is processed out of 432.125
# 90.0th batch is processed out of 432.125
# 91.0th batch is processed out of 432.125
# 92.0th batch is processed out of 432.125
# 93.0th batch is processed out of 432.125
# 94.0th batch is processed out of 432.125
# 95.0th batch is processed out of 432.125
# 96.0th batch is processed out of 432.125
# 97.0th batch is processed out of 432.125
# 98.0th batch is processed out of 432.125
# 99.0th batch is processed out of 432.125
# 100.0th batch is processed out of 432.125
# 101.0th batch is processed out of 432.125
# 102.0th batch is processed out of 432.125
# 103.0th batch is processed out of 432.125
# 104.0th batch is processed out of 432.125
# 105.0th batch is processed out of 432.125
# 106.0th batch is processed out of 432.125
# 107.0th batch is processed out of 432.125
# 108.0th batch is processed out of 432.125
# 109.0th batch is processed out of 432.125
# 110.0th batch is processed out of 432.125
# 111.0th batch is processed out of 432.125
# 112.0th batch is processed out of 432.125
# 113.0th batch is processed out of 432.125
# 114.0th batch is processed out of 432.125
# 115.0th batch is processed out of 432.125
# 116.0th batch is processed out of 432.125
# 117.0th batch is processed out of 432.125
# 118.0th batch is processed out of 432.125
# 119.0th batch is processed out of 432.125
# 120.0th batch is processed out of 432.125
# 121.0th batch is processed out of 432.125
# 122.0th batch is processed out of 432.125
# 123.0th batch is processed out of 432.125
# 124.0th batch is processed out of 432.125
# 125.0th batch is processed out of 432.125
# 126.0th batch is processed out of 432.125
# 127.0th batch is processed out of 432.125
# 128.0th batch is processed out of 432.125
# 129.0th batch is processed out of 432.125
# 130.0th batch is processed out of 432.125
# 131.0th batch is processed out of 432.125
# 132.0th batch is processed out of 432.125
# 133.0th batch is processed out of 432.125
# 134.0th batch is processed out of 432.125
# 135.0th batch is processed out of 432.125
# 136.0th batch is processed out of 432.125
# 137.0th batch is processed out of 432.125
# 138.0th batch is processed out of 432.125
# 139.0th batch is processed out of 432.125
# 140.0th batch is processed out of 432.125
# 141.0th batch is processed out of 432.125
# 142.0th batch is processed out of 432.125
# 143.0th batch is processed out of 432.125
# 144.0th batch is processed out of 432.125
# 145.0th batch is processed out of 432.125
# 146.0th batch is processed out of 432.125
# 147.0th batch is processed out of 432.125
# 148.0th batch is processed out of 432.125
# 149.0th batch is processed out of 432.125
# 150.0th batch is processed out of 432.125
# 151.0th batch is processed out of 432.125
# 152.0th batch is processed out of 432.125
# 153.0th batch is processed out of 432.125
# 154.0th batch is processed out of 432.125
# 155.0th batch is processed out of 432.125
# 156.0th batch is processed out of 432.125
# 157.0th batch is processed out of 432.125
# 158.0th batch is processed out of 432.125
# 159.0th batch is processed out of 432.125
# 160.0th batch is processed out of 432.125
# 161.0th batch is processed out of 432.125
# 162.0th batch is processed out of 432.125
# 163.0th batch is processed out of 432.125
# 164.0th batch is processed out of 432.125
# 165.0th batch is processed out of 432.125
# 166.0th batch is processed out of 432.125
# 167.0th batch is processed out of 432.125
# 168.0th batch is processed out of 432.125
# 169.0th batch is processed out of 432.125
# 170.0th batch is processed out of 432.125
# 171.0th batch is processed out of 432.125
# 172.0th batch is processed out of 432.125
# 173.0th batch is processed out of 432.125
# 174.0th batch is processed out of 432.125
# 175.0th batch is processed out of 432.125
# 176.0th batch is processed out of 432.125
# 177.0th batch is processed out of 432.125
# 178.0th batch is processed out of 432.125
# 179.0th batch is processed out of 432.125
# 180.0th batch is processed out of 432.125
# 181.0th batch is processed out of 432.125
# 182.0th batch is processed out of 432.125
# 183.0th batch is processed out of 432.125
# 184.0th batch is processed out of 432.125
# 185.0th batch is processed out of 432.125
# 186.0th batch is processed out of 432.125
# 187.0th batch is processed out of 432.125
# 188.0th batch is processed out of 432.125
# 189.0th batch is processed out of 432.125
# 190.0th batch is processed out of 432.125
# 191.0th batch is processed out of 432.125
# 192.0th batch is processed out of 432.125
# 193.0th batch is processed out of 432.125
# 194.0th batch is processed out of 432.125
# 195.0th batch is processed out of 432.125
# 196.0th batch is processed out of 432.125
# 197.0th batch is processed out of 432.125
# 198.0th batch is processed out of 432.125
# 199.0th batch is processed out of 432.125
# 200.0th batch is processed out of 432.125
# 201.0th batch is processed out of 432.125
# 202.0th batch is processed out of 432.125
# 203.0th batch is processed out of 432.125
# 204.0th batch is processed out of 432.125
# 205.0th batch is processed out of 432.125
# 206.0th batch is processed out of 432.125
# 207.0th batch is processed out of 432.125
# 208.0th batch is processed out of 432.125
# 209.0th batch is processed out of 432.125
# 210.0th batch is processed out of 432.125
# 211.0th batch is processed out of 432.125
# 212.0th batch is processed out of 432.125
# 213.0th batch is processed out of 432.125
# 214.0th batch is processed out of 432.125
# 215.0th batch is processed out of 432.125
# 216.0th batch is processed out of 432.125
# 217.0th batch is processed out of 432.125
# 218.0th batch is processed out of 432.125
# 219.0th batch is processed out of 432.125
# 220.0th batch is processed out of 432.125
# 221.0th batch is processed out of 432.125
# 222.0th batch is processed out of 432.125
# 223.0th batch is processed out of 432.125
# 224.0th batch is processed out of 432.125
# 225.0th batch is processed out of 432.125
# 226.0th batch is processed out of 432.125
# 227.0th batch is processed out of 432.125
# 228.0th batch is processed out of 432.125
# 229.0th batch is processed out of 432.125
# 230.0th batch is processed out of 432.125
# 231.0th batch is processed out of 432.125
# 232.0th batch is processed out of 432.125
# 233.0th batch is processed out of 432.125
# 234.0th batch is processed out of 432.125
# 235.0th batch is processed out of 432.125
# 236.0th batch is processed out of 432.125
# 237.0th batch is processed out of 432.125
# 238.0th batch is processed out of 432.125
# 239.0th batch is processed out of 432.125
# 240.0th batch is processed out of 432.125
# 241.0th batch is processed out of 432.125
# 242.0th batch is processed out of 432.125
# 243.0th batch is processed out of 432.125
# 244.0th batch is processed out of 432.125
# 245.0th batch is processed out of 432.125
# 246.0th batch is processed out of 432.125
# 247.0th batch is processed out of 432.125
# 248.0th batch is processed out of 432.125
# 249.0th batch is processed out of 432.125
# 250.0th batch is processed out of 432.125
# 251.0th batch is processed out of 432.125
# 252.0th batch is processed out of 432.125
# 253.0th batch is processed out of 432.125
# 254.0th batch is processed out of 432.125
# 255.0th batch is processed out of 432.125
# 256.0th batch is processed out of 432.125
# 257.0th batch is processed out of 432.125
# 258.0th batch is processed out of 432.125
# 259.0th batch is processed out of 432.125
# 260.0th batch is processed out of 432.125
# 261.0th batch is processed out of 432.125
# 262.0th batch is processed out of 432.125
# 263.0th batch is processed out of 432.125
# 264.0th batch is processed out of 432.125
# 265.0th batch is processed out of 432.125
# 266.0th batch is processed out of 432.125
# 267.0th batch is processed out of 432.125
# 268.0th batch is processed out of 432.125
# 269.0th batch is processed out of 432.125
# 270.0th batch is processed out of 432.125
# 271.0th batch is processed out of 432.125
# 272.0th batch is processed out of 432.125
# 273.0th batch is processed out of 432.125
# 274.0th batch is processed out of 432.125
# 275.0th batch is processed out of 432.125
# 276.0th batch is processed out of 432.125
# 277.0th batch is processed out of 432.125
# 278.0th batch is processed out of 432.125
# 279.0th batch is processed out of 432.125
# 280.0th batch is processed out of 432.125
# 281.0th batch is processed out of 432.125
# 282.0th batch is processed out of 432.125
# 283.0th batch is processed out of 432.125
# 284.0th batch is processed out of 432.125
# 285.0th batch is processed out of 432.125
# 286.0th batch is processed out of 432.125
# 287.0th batch is processed out of 432.125
# 288.0th batch is processed out of 432.125
# 289.0th batch is processed out of 432.125
# 290.0th batch is processed out of 432.125
# 291.0th batch is processed out of 432.125
# 292.0th batch is processed out of 432.125
# 293.0th batch is processed out of 432.125
# 294.0th batch is processed out of 432.125
# 295.0th batch is processed out of 432.125
# 296.0th batch is processed out of 432.125
# 297.0th batch is processed out of 432.125
# 298.0th batch is processed out of 432.125
# 299.0th batch is processed out of 432.125
# 300.0th batch is processed out of 432.125
# 301.0th batch is processed out of 432.125
# 302.0th batch is processed out of 432.125
# 303.0th batch is processed out of 432.125
# 304.0th batch is processed out of 432.125
# 305.0th batch is processed out of 432.125
# 306.0th batch is processed out of 432.125
# 307.0th batch is processed out of 432.125
# 308.0th batch is processed out of 432.125
# 309.0th batch is processed out of 432.125
# 310.0th batch is processed out of 432.125
# 311.0th batch is processed out of 432.125
# 312.0th batch is processed out of 432.125
# 313.0th batch is processed out of 432.125
# 314.0th batch is processed out of 432.125
# 315.0th batch is processed out of 432.125
# 316.0th batch is processed out of 432.125
# 317.0th batch is processed out of 432.125
# 318.0th batch is processed out of 432.125
# 319.0th batch is processed out of 432.125
# 320.0th batch is processed out of 432.125
# 321.0th batch is processed out of 432.125
# 322.0th batch is processed out of 432.125
# 323.0th batch is processed out of 432.125
# 324.0th batch is processed out of 432.125
# 325.0th batch is processed out of 432.125
# 326.0th batch is processed out of 432.125
# 327.0th batch is processed out of 432.125
# 328.0th batch is processed out of 432.125
# 329.0th batch is processed out of 432.125
# 330.0th batch is processed out of 432.125
# 331.0th batch is processed out of 432.125
# 332.0th batch is processed out of 432.125
# 333.0th batch is processed out of 432.125
# 334.0th batch is processed out of 432.125
# 335.0th batch is processed out of 432.125
# 336.0th batch is processed out of 432.125
# 337.0th batch is processed out of 432.125
# 338.0th batch is processed out of 432.125
# 339.0th batch is processed out of 432.125
# 340.0th batch is processed out of 432.125
# 341.0th batch is processed out of 432.125
# 342.0th batch is processed out of 432.125
# 343.0th batch is processed out of 432.125
# 344.0th batch is processed out of 432.125
# 345.0th batch is processed out of 432.125
# 346.0th batch is processed out of 432.125
# 347.0th batch is processed out of 432.125
# 348.0th batch is processed out of 432.125
# 349.0th batch is processed out of 432.125
# 350.0th batch is processed out of 432.125
# 351.0th batch is processed out of 432.125
# 352.0th batch is processed out of 432.125
# 353.0th batch is processed out of 432.125
# 354.0th batch is processed out of 432.125
# 355.0th batch is processed out of 432.125
# 356.0th batch is processed out of 432.125
# 357.0th batch is processed out of 432.125
# 358.0th batch is processed out of 432.125
# 359.0th batch is processed out of 432.125
# 360.0th batch is processed out of 432.125
# 361.0th batch is processed out of 432.125
# 362.0th batch is processed out of 432.125
# 363.0th batch is processed out of 432.125
# 364.0th batch is processed out of 432.125
# 365.0th batch is processed out of 432.125
# 366.0th batch is processed out of 432.125
# 367.0th batch is processed out of 432.125
# 368.0th batch is processed out of 432.125
# 369.0th batch is processed out of 432.125
# 370.0th batch is processed out of 432.125
# 371.0th batch is processed out of 432.125
# 372.0th batch is processed out of 432.125
# 373.0th batch is processed out of 432.125
# 374.0th batch is processed out of 432.125
# 375.0th batch is processed out of 432.125
# 376.0th batch is processed out of 432.125
# 377.0th batch is processed out of 432.125
# 378.0th batch is processed out of 432.125
# 379.0th batch is processed out of 432.125
# 380.0th batch is processed out of 432.125
# 381.0th batch is processed out of 432.125
# 382.0th batch is processed out of 432.125
# 383.0th batch is processed out of 432.125
# 384.0th batch is processed out of 432.125
# 385.0th batch is processed out of 432.125
# 386.0th batch is processed out of 432.125
# 387.0th batch is processed out of 432.125
# 388.0th batch is processed out of 432.125
# 389.0th batch is processed out of 432.125
# 390.0th batch is processed out of 432.125
# 391.0th batch is processed out of 432.125
# 392.0th batch is processed out of 432.125
# 393.0th batch is processed out of 432.125
# 394.0th batch is processed out of 432.125
# 395.0th batch is processed out of 432.125
# 396.0th batch is processed out of 432.125
# 397.0th batch is processed out of 432.125
# 398.0th batch is processed out of 432.125
# 399.0th batch is processed out of 432.125
# 400.0th batch is processed out of 432.125
# 401.0th batch is processed out of 432.125
# 402.0th batch is processed out of 432.125
# 403.0th batch is processed out of 432.125
# 404.0th batch is processed out of 432.125
# 405.0th batch is processed out of 432.125
# 406.0th batch is processed out of 432.125
# 407.0th batch is processed out of 432.125
# 408.0th batch is processed out of 432.125
# 409.0th batch is processed out of 432.125
# 410.0th batch is processed out of 432.125
# 411.0th batch is processed out of 432.125
# 412.0th batch is processed out of 432.125
# 413.0th batch is processed out of 432.125
# 414.0th batch is processed out of 432.125
# 415.0th batch is processed out of 432.125
# 416.0th batch is processed out of 432.125
# 417.0th batch is processed out of 432.125
# 418.0th batch is processed out of 432.125
# 419.0th batch is processed out of 432.125
# 420.0th batch is processed out of 432.125
# 421.0th batch is processed out of 432.125
# 422.0th batch is processed out of 432.125
# 423.0th batch is processed out of 432.125
# 424.0th batch is processed out of 432.125
# 425.0th batch is processed out of 432.125
# 426.0th batch is processed out of 432.125
# 427.0th batch is processed out of 432.125
# 428.0th batch is processed out of 432.125
# 429.0th batch is processed out of 432.125
# 430.0th batch is processed out of 432.125
# 431.0th batch is processed out of 432.125
# 432.0th batch is processed out of 432.125
# all batches processed completely
# aligned data size:68348
# aligned data size:68348
# aligned data size:68348

# %%
# @title Function to save model's current state to drive
def save_checkpoint(layer_idx, encoder, decoder, optimizer, current_epoch,task):
    checkpoint = {
        'encoder_state_dict': encoder.state_dict(),
        'decoder_state_dict': decoder.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'epoch': current_epoch
    }
    CHECKPOINT_DIR=f"/content/drive/MyDrive/SAE_outputs/sae_checkpoints_{task}"
    if(not os.path.exists(CHECKPOINT_DIR)):
          os.makedirs(CHECKPOINT_DIR, exist_ok=True)
    torch.save(checkpoint, f"{CHECKPOINT_DIR}/layer_{layer_idx}_model.pt")

# %%
# @title Function to load model's current state from drive
def load_checkpoint(layer_idx, encoder, decoder, optimizer,task,resume):
  if resume=='c':
    return 0

    checkpoint_path = f"/content/drive/MyDrive/SAE_outputs/sae_checkpoints_{task}/layer_{layer_idx}_model.pt"
    print(checkpoint_path)
    if os.path.exists(checkpoint_path):
        checkpoint = torch.load(checkpoint_path)
        encoder.load_state_dict(checkpoint['encoder_state_dict'])
        decoder.load_state_dict(checkpoint['decoder_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        if(resume=='b'):
          return checkpoint.get('epoch', 0)
        else:
          return 0
    print('couldnt found the file, starting from scretch')
    return 0

# %%
# @title Function that applies topK sparsity
def _apply_top_k_sparsity(activations, k):
    top_values, top_indices = torch.topk(torch.abs(activations), k, dim=1)
    sparse_activations = torch.zeros_like(activations)
    row_idx = torch.arange(activations.size(0)).unsqueeze(1).expand(-1, k)
    sparse_activations[row_idx, top_indices] = activations[row_idx, top_indices]
    return sparse_activations

# %%
# @title Function to train Sparse autoencoder for a layer
def train_sparse_autoencoder(hidden_states, layer_idx,device, resume, task, sae_dim=2048, sparsity_coeff=0.01,
                           top_k=50, epochs=100, lr=0.001 , batch_size=131072):

        all_tokens = []
        hidden_dim =hidden_states[layer_idx][0].shape[-1]
        with torch.no_grad():
          all_tokens = torch.cat([
              batch.view(-1, hidden_dim) for batch in hidden_states[layer_idx]
          ], dim=0).to(device)





        encoder = torch.nn.Linear(hidden_dim, sae_dim, bias=True).to(device)
        decoder = torch.nn.Linear(sae_dim, hidden_dim, bias=False).to(device)
        torch.nn.init.xavier_uniform_(encoder.weight)
        torch.nn.init.xavier_uniform_(decoder.weight)
        optimizer = torch.optim.Adam(list(encoder.parameters()) + list(decoder.parameters()), lr=lr)


        start_epoch = load_checkpoint(layer_idx, encoder, decoder, optimizer,task,resume)

        dataset = torch.utils.data.TensorDataset(all_tokens)
        dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True) #splits into batches of shuffled hidden vectors while preserving the shape

        try:

            for epoch in range(start_epoch,epochs):
                total_loss = 0
                total_recon_loss = 0
                total_sparsity_loss = 0

                for batch_idx, (batch_vectors,) in enumerate(dataloader):
                    batch_vectors = batch_vectors.to(device)
                    raw_activations = encoder(batch_vectors)
                    sparse_activations = _apply_top_k_sparsity(raw_activations, top_k)
                    reconstructed = decoder(sparse_activations)
                    recon_loss = torch.nn.functional.mse_loss(reconstructed, batch_vectors)
                    sparsity_loss = torch.mean(torch.abs(sparse_activations))



                    total_loss_batch = recon_loss + sparsity_coeff * sparsity_loss
                    optimizer.zero_grad()#clears previous gradients
                    total_loss_batch.backward()#computes gradients
                    optimizer.step()#updates the weights θ=θ−η⋅gradient n is the learning rate

                    total_loss += total_loss_batch.item()
                    total_recon_loss += recon_loss.item()
                    total_sparsity_loss += sparsity_loss.item()

                if epoch % 10 == 0:
                    avg_loss = total_loss / len(dataloader)
                    avg_recon = total_recon_loss / len(dataloader)
                    avg_sparsity = total_sparsity_loss / len(dataloader)
                    print(f"Epoch {epoch}: avg-Loss={avg_loss:.4f}, Recon={avg_recon:.4f}, Sparsity={avg_sparsity:.4f} of layer{layer_idx}")

        except KeyboardInterrupt:
          print(f"\nTraining interrupted at epoch {epoch}. Saving checkpoint for layer {layer_idx}...")
          save_checkpoint(layer_idx, encoder, decoder, optimizer, epoch,task)


        save_checkpoint(layer_idx, encoder, decoder, optimizer, epoch,task)

        encoder.eval()
        decoder.eval()

# %%
# @title Function to Train the Encoder for all layers based on a task
import torch
from concurrent.futures import ThreadPoolExecutor
def _training_all_encoders_(task,hidden_states,device):
  max_parallel=6
  # resume=input('retrain or resume from last epoch or start training from scratch? a/b/c ')
  resume='c'
  def wrapped(layer_idx):
    print(f"🔧 Training SAE for layer {layer_idx} of task '{task}'", flush=True)
    return train_sparse_autoencoder(hidden_states, layer_idx, device, resume, task)

  with ThreadPoolExecutor(max_workers=max_parallel) as executor:
    executor.map(wrapped, range(num_layers))

  print(f"✅ Finished all layers for task '{task}'")

# %%
import os
from google.colab import drive
if( not os.path.exists('/content/drive')):
      drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# @title Code to execute the training of Encoder
import os, torch, pickle



tasks = ['pos','dep',"position"]


if os.path.exists("last_task.txt"):
  with open("last_task.txt", "r") as f:
    completed_tasks=f.read().strip()

else:
  completed_tasks=''
  open("last_task.txt", "w")


hidden_states=all_hidden_states

for each_task in tasks:
  if each_task in completed_tasks.split(' '):
    continue
  try:
    print(f"started training for task {each_task}")
    sae_models=_training_all_encoders_(each_task,hidden_states,device)

  except KeyboardInterrupt:
    print(f"\nTraining interrupted at task {each_task}.")
    break


  with open("last_task.txt", "a") as f:
    f.write(each_task+' ')
# Out:
# started training for task pos
# 🔧 Training SAE for layer 0 of task 'pos'
# 🔧 Training SAE for layer 1 of task 'pos'
# 🔧 Training SAE for layer 2 of task 'pos'
# 🔧 Training SAE for layer 3 of task 'pos'
# 🔧 Training SAE for layer 4 of task 'pos'
# 🔧 Training SAE for layer 5 of task 'pos'
# Epoch 0: avg-Loss=0.3539, Recon=0.3537, Sparsity=0.0242 of layer1
# Epoch 0: avg-Loss=0.2654, Recon=0.2652, Sparsity=0.0211 of layer0
# Epoch 0: avg-Loss=0.7324, Recon=0.7320, Sparsity=0.0333 of layer4
# Epoch 0: avg-Loss=0.6136, Recon=0.6133, Sparsity=0.0313 of layer3
# Epoch 0: avg-Loss=0.1436, Recon=0.1435, Sparsity=0.0154 of layer5
#
# Training interrupted at task pos.

# %%
# @title Function to interpret strongly activated features for a layer
def _find_interpretable_features(all_features, aligned_data, top_n=10):

        interpretable_features = []
        num_features = all_features.shape[1]

        for feature_idx in range(num_features):
            feature_activations = all_features[:, feature_idx]
            threshold = torch.quantile(feature_activations, 0.90)
            strong_positions = torch.where(feature_activations > threshold)[0]

            if len(strong_positions) < 5:
                continue

            labels_for_feature = []
            for pos in strong_positions:
                labels_for_feature.append(aligned_data[pos.item()]['label']) #aligned data is a list of dictionary representing each token , each token data is just appended

            if labels_for_feature:
                from collections import Counter
                label_counts = Counter(labels_for_feature)
                most_common_count = label_counts.most_common(1)[0][1]
                consistency = most_common_count / len(labels_for_feature)

                interpretable_features.append({
                    'feature_idx': feature_idx,
                    'consistency': consistency,
                    'dominant_label': label_counts.most_common(1)[0][0],
                    'activation_count': len(strong_positions),
                    'label_distribution': dict(label_counts.most_common(5))
                })

        '''
            interpretable_features = [
        {'feature_idx': 5, 'consistency': 0.87},
        {'feature_idx': 2, 'consistency': 0.93},
        {'feature_idx': 7, 'consistency': 0.76}
        ]

        '''

        interpretable_features.sort(key=lambda x: x['consistency'], reverse=True)
        return interpretable_features[:top_n]

# %%
# @title Function to compute relation of label and activation score using MI
from sklearn.metrics import mutual_info_score
from collections import defaultdict, Counter

def compute_label_mi(all_features, aligned_data, interpretable_features, threshold=0.5):
    label_mi_scores = defaultdict(float)  # cumulative MI per label

    # Flattened labels per sample
    all_labels = [data["label"] for data in aligned_data]  # or data["labels"] if multilabel
    all_labels = np.array(all_labels)

    for feature in interpretable_features:
        idx = feature["feature_idx"]
        activations = all_features[:, idx].detach().cpu().numpy()

        # Binarize activations (top-k or threshold)
        top_indices = activations.argsort()[-100:]  # top 100 activations (tune as needed)
        bin_activations = np.zeros_like(activations)
        bin_activations[top_indices] = 1

        # Align labels (assumes one label per sample, adapt for multilabel)
        mi = mutual_info_score(bin_activations, all_labels)

        # Count labels among top activations
        top_labels = [all_labels[i] for i in top_indices]
        top_label_counts = Counter(top_labels)

        for label, count in top_label_counts.items():
            label_mi_scores[label] += mi * (count / len(top_indices))  # weight MI by how dominant label is

    # Sort by MI
    sorted_mi_labels = sorted(label_mi_scores.items(), key=lambda x: x[1], reverse=True)
    return sorted_mi_labels[:5]  # top 5 labels

# %%
# @title Function to test a Trained encoder
def test_sparse_autoencoder(sae_model, hidden_states, aligned_data,device,top_k=50):

        layer_idx = sae_model['layer_idx']
        encoder = sae_model['encoder']
        top_k = top_k


        all_features = []


        encoder.eval()

        with torch.no_grad():
            for each_batch in hidden_states[layer_idx]:
                batch_size, seq_len, hidden_dim = each_batch.shape
                each_batch_combined_tokens = each_batch.view(-1, hidden_dim).to(device)
                raw_activations = encoder(each_batch_combined_tokens)
                sparse_features = _apply_top_k_sparsity(raw_activations, top_k)
                all_features.append(sparse_features.cpu())

        all_features = torch.cat(all_features, dim=0)



        interpretable_features =_find_interpretable_features(all_features, aligned_data, top_n=10)

        label_mi_list = compute_label_mi(all_features, aligned_data, interpretable_features)

        return {
            'layer_idx': layer_idx,
            'features': all_features,
            'interpretable_features': interpretable_features,
            'label_mi_list': label_mi_list

        }

# %%
# @title Function to test Trained encoders from all layers
from concurrent.futures import ThreadPoolExecutor

def _testing_all_encoders_(sae_models,hidden_states,aligned_data,device,task):
  max_parallel=6
  each_task_sae_results = {}

  def wrapped(layer_idx):
    print(f" Testing SAE for layer {layer_idx} of task '{task}'", flush=True)
    return test_sparse_autoencoder(sae_models[layer_idx], hidden_states, aligned_data,device)

  with ThreadPoolExecutor(max_workers=max_parallel) as executor:
    futures = executor.map(wrapped, range(num_layers))

    for layer_idx, result in enumerate(futures):
      each_task_sae_results[layer_idx] = result
  print(f" Finished testing all layers for task '{task}'")
  return each_task_sae_results

# %%
sentences,labels_dict=prepare_data(test=True)


for i in labels_dict:
  labels_dict[i]=labels_dict[i][:round(0.1*len(sentences))]
sentences=sentences[:round(0.1*len(sentences))]


hidden_states,all_task_alignedData=_extract_representations(sentences, labels_dict,tokenizer,num_layers,model,device)
# Out:
# 0.0th batch is processed out of 156.75
# 1.0th batch is processed out of 156.75
# 2.0th batch is processed out of 156.75
# 3.0th batch is processed out of 156.75
# 4.0th batch is processed out of 156.75
# 5.0th batch is processed out of 156.75
# 6.0th batch is processed out of 156.75
# 7.0th batch is processed out of 156.75
# 8.0th batch is processed out of 156.75
# 9.0th batch is processed out of 156.75
# 10.0th batch is processed out of 156.75
# 11.0th batch is processed out of 156.75
# 12.0th batch is processed out of 156.75
# 13.0th batch is processed out of 156.75
# 14.0th batch is processed out of 156.75
# 15.0th batch is processed out of 156.75
# 16.0th batch is processed out of 156.75
# 17.0th batch is processed out of 156.75
# 18.0th batch is processed out of 156.75
# 19.0th batch is processed out of 156.75
# 20.0th batch is processed out of 156.75
# 21.0th batch is processed out of 156.75
# 22.0th batch is processed out of 156.75
# 23.0th batch is processed out of 156.75
# 24.0th batch is processed out of 156.75
# 25.0th batch is processed out of 156.75
# 26.0th batch is processed out of 156.75
# 27.0th batch is processed out of 156.75
# 28.0th batch is processed out of 156.75
# 29.0th batch is processed out of 156.75
# 30.0th batch is processed out of 156.75
# 31.0th batch is processed out of 156.75
# 32.0th batch is processed out of 156.75
# 33.0th batch is processed out of 156.75
# 34.0th batch is processed out of 156.75
# 35.0th batch is processed out of 156.75
# 36.0th batch is processed out of 156.75
# 37.0th batch is processed out of 156.75
# 38.0th batch is processed out of 156.75
# 39.0th batch is processed out of 156.75
# 40.0th batch is processed out of 156.75
# 41.0th batch is processed out of 156.75
# 42.0th batch is processed out of 156.75
# 43.0th batch is processed out of 156.75
# 44.0th batch is processed out of 156.75
# 45.0th batch is processed out of 156.75
# 46.0th batch is processed out of 156.75
# 47.0th batch is processed out of 156.75
# 48.0th batch is processed out of 156.75
# 49.0th batch is processed out of 156.75
# 50.0th batch is processed out of 156.75
# 51.0th batch is processed out of 156.75
# 52.0th batch is processed out of 156.75
# 53.0th batch is processed out of 156.75
# 54.0th batch is processed out of 156.75
# 55.0th batch is processed out of 156.75
# 56.0th batch is processed out of 156.75
# 57.0th batch is processed out of 156.75
# 58.0th batch is processed out of 156.75
# 59.0th batch is processed out of 156.75
# 60.0th batch is processed out of 156.75
# 61.0th batch is processed out of 156.75
# 62.0th batch is processed out of 156.75
# 63.0th batch is processed out of 156.75
# 64.0th batch is processed out of 156.75
# 65.0th batch is processed out of 156.75
# 66.0th batch is processed out of 156.75
# 67.0th batch is processed out of 156.75
# 68.0th batch is processed out of 156.75
# 69.0th batch is processed out of 156.75
# 70.0th batch is processed out of 156.75
# 71.0th batch is processed out of 156.75
# 72.0th batch is processed out of 156.75
# 73.0th batch is processed out of 156.75
# 74.0th batch is processed out of 156.75
# 75.0th batch is processed out of 156.75
# 76.0th batch is processed out of 156.75
# 77.0th batch is processed out of 156.75
# 78.0th batch is processed out of 156.75
# 79.0th batch is processed out of 156.75
# 80.0th batch is processed out of 156.75
# 81.0th batch is processed out of 156.75
# 82.0th batch is processed out of 156.75
# 83.0th batch is processed out of 156.75
# 84.0th batch is processed out of 156.75
# 85.0th batch is processed out of 156.75
# 86.0th batch is processed out of 156.75
# 87.0th batch is processed out of 156.75
# 88.0th batch is processed out of 156.75
# 89.0th batch is processed out of 156.75
# 90.0th batch is processed out of 156.75
# 91.0th batch is processed out of 156.75
# 92.0th batch is processed out of 156.75
# 93.0th batch is processed out of 156.75
# 94.0th batch is processed out of 156.75
# 95.0th batch is processed out of 156.75
# 96.0th batch is processed out of 156.75
# 97.0th batch is processed out of 156.75
# 98.0th batch is processed out of 156.75
# 99.0th batch is processed out of 156.75
# 100.0th batch is processed out of 156.75
# 101.0th batch is processed out of 156.75
# 102.0th batch is processed out of 156.75
# 103.0th batch is processed out of 156.75
# 104.0th batch is processed out of 156.75
# 105.0th batch is processed out of 156.75
# 106.0th batch is processed out of 156.75
# 107.0th batch is processed out of 156.75
# 108.0th batch is processed out of 156.75
# 109.0th batch is processed out of 156.75
# 110.0th batch is processed out of 156.75
# 111.0th batch is processed out of 156.75
# 112.0th batch is processed out of 156.75
# 113.0th batch is processed out of 156.75
# 114.0th batch is processed out of 156.75
# 115.0th batch is processed out of 156.75
# 116.0th batch is processed out of 156.75
# 117.0th batch is processed out of 156.75
# 118.0th batch is processed out of 156.75
# 119.0th batch is processed out of 156.75
# 120.0th batch is processed out of 156.75
# 121.0th batch is processed out of 156.75
# 122.0th batch is processed out of 156.75
# 123.0th batch is processed out of 156.75
# 124.0th batch is processed out of 156.75
# 125.0th batch is processed out of 156.75
# 126.0th batch is processed out of 156.75
# 127.0th batch is processed out of 156.75
# 128.0th batch is processed out of 156.75
# 129.0th batch is processed out of 156.75
# 130.0th batch is processed out of 156.75
# 131.0th batch is processed out of 156.75
# 132.0th batch is processed out of 156.75
# 133.0th batch is processed out of 156.75
# 134.0th batch is processed out of 156.75
# 135.0th batch is processed out of 156.75
# 136.0th batch is processed out of 156.75
# 137.0th batch is processed out of 156.75
# 138.0th batch is processed out of 156.75
# 139.0th batch is processed out of 156.75
# 140.0th batch is processed out of 156.75
# 141.0th batch is processed out of 156.75
# 142.0th batch is processed out of 156.75
# 143.0th batch is processed out of 156.75
# 144.0th batch is processed out of 156.75
# 145.0th batch is processed out of 156.75
# 146.0th batch is processed out of 156.75
# 147.0th batch is processed out of 156.75
# 148.0th batch is processed out of 156.75
# 149.0th batch is processed out of 156.75
# 150.0th batch is processed out of 156.75
# 151.0th batch is processed out of 156.75
# 152.0th batch is processed out of 156.75
# 153.0th batch is processed out of 156.75
# 154.0th batch is processed out of 156.75
# 155.0th batch is processed out of 156.75
# 156.0th batch is processed out of 156.75
# all batches processed completely
# Aligned data size: 344
# Aligned data size: 344
# Aligned data size: 344
# Aligned data size: 328
# Aligned data size: 328
# Aligned data size: 328
# Aligned data size: 400
# Aligned data size: 400
# Aligned data size: 400
# Aligned data size: 472
# Aligned data size: 472
# Aligned data size: 472
# Aligned data size: 280
# Aligned data size: 280
# Aligned data size: 280
# Aligned data size: 456
# Aligned data size: 456
# Aligned data size: 456
# Aligned data size: 688
# Aligned data size: 688
# Aligned data size: 688
# Aligned data size: 640
# Aligned data size: 640
# Aligned data size: 640
# Aligned data size: 656
# Aligned data size: 656
# Aligned data size: 656
# Aligned data size: 464
# Aligned data size: 464
# Aligned data size: 464
# Aligned data size: 544
# Aligned data size: 544
# Aligned data size: 544
# Aligned data size: 296
# Aligned data size: 296
# Aligned data size: 296
# Aligned data size: 240
# Aligned data size: 240
# Aligned data size: 240
# Aligned data size: 224
# Aligned data size: 224
# Aligned data size: 224
# Aligned data size: 480
# Aligned data size: 480
# Aligned data size: 480
# Aligned data size: 384
# Aligned data size: 384
# Aligned data size: 384
# Aligned data size: 392
# Aligned data size: 392
# Aligned data size: 392
# Aligned data size: 376
# Aligned data size: 376
# Aligned data size: 376
# Aligned data size: 432
# Aligned data size: 432
# Aligned data size: 432
# Aligned data size: 280
# Aligned data size: 280
# Aligned data size: 280
# Aligned data size: 472
# Aligned data size: 472
# Aligned data size: 472
# Aligned data size: 368
# Aligned data size: 368
# Aligned data size: 368
# Aligned data size: 336
# Aligned data size: 336
# Aligned data size: 336
# Aligned data size: 584
# Aligned data size: 584
# Aligned data size: 584
# Aligned data size: 392
# Aligned data size: 392
# Aligned data size: 392
# Aligned data size: 384
# Aligned data size: 384
# Aligned data size: 384
# Aligned data size: 392
# Aligned data size: 392
# Aligned data size: 392
# Aligned data size: 368
# Aligned data size: 368
# Aligned data size: 368
# Aligned data size: 320
# Aligned data size: 320
# Aligned data size: 320
# Aligned data size: 488
# Aligned data size: 488
# Aligned data size: 488
# Aligned data size: 376
# Aligned data size: 376
# Aligned data size: 376
# Aligned data size: 536
# Aligned data size: 536
# Aligned data size: 536
# Aligned data size: 400
# Aligned data size: 400
# Aligned data size: 400
# Aligned data size: 672
# Aligned data size: 672
# Aligned data size: 672
# Aligned data size: 496
# Aligned data size: 496
# Aligned data size: 496
# Aligned data size: 544
# Aligned data size: 544
# Aligned data size: 544
# Aligned data size: 400
# Aligned data size: 400
# Aligned data size: 400
# Aligned data size: 504
# Aligned data size: 504
# Aligned data size: 504
# Aligned data size: 496
# Aligned data size: 496
# Aligned data size: 496
# Aligned data size: 544
# Aligned data size: 544
# Aligned data size: 544
# Aligned data size: 632
# Aligned data size: 632
# Aligned data size: 632
# Aligned data size: 312
# Aligned data size: 312
# Aligned data size: 312
# Aligned data size: 264
# Aligned data size: 264
# Aligned data size: 264
# Aligned data size: 264
# Aligned data size: 264
# Aligned data size: 264
# Aligned data size: 168
# Aligned data size: 168
# Aligned data size: 168
# Aligned data size: 376
# Aligned data size: 376
# Aligned data size: 376
# Aligned data size: 480
# Aligned data size: 480
# Aligned data size: 480
# Aligned data size: 264
# Aligned data size: 264
# Aligned data size: 264
# Aligned data size: 272
# Aligned data size: 272
# Aligned data size: 272
# Aligned data size: 344
# Aligned data size: 344
# Aligned data size: 344
# Aligned data size: 176
# Aligned data size: 176
# Aligned data size: 176
# Aligned data size: 368
# Aligned data size: 368
# Aligned data size: 368
# Aligned data size: 560
# Aligned data size: 560
# Aligned data size: 560
# Aligned data size: 320
# Aligned data size: 320
# Aligned data size: 320
# Aligned data size: 456
# Aligned data size: 456
# Aligned data size: 456
# Aligned data size: 552
# Aligned data size: 552
# Aligned data size: 552
# Aligned data size: 424
# Aligned data size: 424
# Aligned data size: 424
# Aligned data size: 208
# Aligned data size: 208
# Aligned data size: 208
# Aligned data size: 208
# Aligned data size: 208
# Aligned data size: 208
# Aligned data size: 520
# Aligned data size: 520
# Aligned data size: 520
# Aligned data size: 264
# Aligned data size: 264
# Aligned data size: 264
# Aligned data size: 256
# Aligned data size: 256
# Aligned data size: 256
# Aligned data size: 704
# Aligned data size: 704
# Aligned data size: 704
# Aligned data size: 560
# Aligned data size: 560
# Aligned data size: 560
# Aligned data size: 328
# Aligned data size: 328
# Aligned data size: 328
# Aligned data size: 552
# Aligned data size: 552
# Aligned data size: 552
# Aligned data size: 208
# Aligned data size: 208
# Aligned data size: 208
# Aligned data size: 136
# Aligned data size: 136
# Aligned data size: 136
# Aligned data size: 336
# Aligned data size: 336
# Aligned data size: 336
# Aligned data size: 560
# Aligned data size: 560
# Aligned data size: 560
# Aligned data size: 448
# Aligned data size: 448
# Aligned data size: 448
# Aligned data size: 576
# Aligned data size: 576
# Aligned data size: 576
# Aligned data size: 352
# Aligned data size: 352
# Aligned data size: 352
# Aligned data size: 552
# Aligned data size: 552
# Aligned data size: 552
# Aligned data size: 376
# Aligned data size: 376
# Aligned data size: 376
# Aligned data size: 384
# Aligned data size: 384
# Aligned data size: 384
# Aligned data size: 560
# Aligned data size: 560
# Aligned data size: 560
# Aligned data size: 312
# Aligned data size: 312
# Aligned data size: 312
# Aligned data size: 288
# Aligned data size: 288
# Aligned data size: 288
# Aligned data size: 376
# Aligned data size: 376
# Aligned data size: 376
# Aligned data size: 536
# Aligned data size: 536
# Aligned data size: 536
# Aligned data size: 272
# Aligned data size: 272
# Aligned data size: 272
# Aligned data size: 392
# Aligned data size: 392
# Aligned data size: 392
# Aligned data size: 448
# Aligned data size: 448
# Aligned data size: 448
# Aligned data size: 368
# Aligned data size: 368
# Aligned data size: 368
# Aligned data size: 536
# Aligned data size: 536
# Aligned data size: 536
# Aligned data size: 552
# Aligned data size: 552
# Aligned data size: 552
# Aligned data size: 432
# Aligned data size: 432
# Aligned data size: 432
# Aligned data size: 288
# Aligned data size: 288
# Aligned data size: 288
# Aligned data size: 480
# Aligned data size: 480
# Aligned data size: 480
# Aligned data size: 368
# Aligned data size: 368
# Aligned data size: 368
# Aligned data size: 344
# Aligned data size: 344
# Aligned data size: 344
# Aligned data size: 448
# Aligned data size: 448
# Aligned data size: 448
# Aligned data size: 224
# Aligned data size: 224
# Aligned data size: 224
# Aligned data size: 232
# Aligned data size: 232
# Aligned data size: 232
# Aligned data size: 312
# Aligned data size: 312
# Aligned data size: 312
# Aligned data size: 448
# Aligned data size: 448
# Aligned data size: 448
# Aligned data size: 360
# Aligned data size: 360
# Aligned data size: 360
# Aligned data size: 440
# Aligned data size: 440
# Aligned data size: 440
# Aligned data size: 208
# Aligned data size: 208
# Aligned data size: 208
# Aligned data size: 216
# Aligned data size: 216
# Aligned data size: 216
# Aligned data size: 256
# Aligned data size: 256
# Aligned data size: 256
# Aligned data size: 360
# Aligned data size: 360
# Aligned data size: 360
# Aligned data size: 472
# Aligned data size: 472
# Aligned data size: 472
# Aligned data size: 480
# Aligned data size: 480
# Aligned data size: 480
# Aligned data size: 368
# Aligned data size: 368
# Aligned data size: 368
# Aligned data size: 384
# Aligned data size: 384
# Aligned data size: 384
# Aligned data size: 848
# Aligned data size: 848
# Aligned data size: 848
# Aligned data size: 648
# Aligned data size: 648
# Aligned data size: 648
# Aligned data size: 192
# Aligned data size: 192
# Aligned data size: 192
# Aligned data size: 264
# Aligned data size: 264
# Aligned data size: 264
# Aligned data size: 248
# Aligned data size: 248
# Aligned data size: 248
# Aligned data size: 248
# Aligned data size: 248
# Aligned data size: 248
# Aligned data size: 368
# Aligned data size: 368
# Aligned data size: 368
# Aligned data size: 504
# Aligned data size: 504
# Aligned data size: 504
# Aligned data size: 344
# Aligned data size: 344
# Aligned data size: 344
# Aligned data size: 248
# Aligned data size: 248
# Aligned data size: 248
# Aligned data size: 328
# Aligned data size: 328
# Aligned data size: 328
# Aligned data size: 296
# Aligned data size: 296
# Aligned data size: 296
# Aligned data size: 584
# Aligned data size: 584
# Aligned data size: 584
# Aligned data size: 272
# Aligned data size: 272
# Aligned data size: 272
# Aligned data size: 344
# Aligned data size: 344
# Aligned data size: 344
# Aligned data size: 368
# Aligned data size: 368
# Aligned data size: 368
# Aligned data size: 360
# Aligned data size: 360
# Aligned data size: 360
# Aligned data size: 272
# Aligned data size: 272
# Aligned data size: 272
# Aligned data size: 448
# Aligned data size: 448
# Aligned data size: 448
# Aligned data size: 456
# Aligned data size: 456
# Aligned data size: 456
# Aligned data size: 344
# Aligned data size: 344
# Aligned data size: 344
# Aligned data size: 240
# Aligned data size: 240
# Aligned data size: 240
# Aligned data size: 424
# Aligned data size: 424
# Aligned data size: 424
# Aligned data size: 184
# Aligned data size: 184
# Aligned data size: 184
# Aligned data size: 296
# Aligned data size: 296
# Aligned data size: 296
# Aligned data size: 320
# Aligned data size: 320
# Aligned data size: 320
# Aligned data size: 368
# Aligned data size: 368
# Aligned data size: 368
# Aligned data size: 296
# Aligned data size: 296
# Aligned data size: 296
# Aligned data size: 264
# Aligned data size: 264
# Aligned data size: 264
# Aligned data size: 488
# Aligned data size: 488
# Aligned data size: 488
# Aligned data size: 392
# Aligned data size: 392
# Aligned data size: 392
# Aligned data size: 400
# Aligned data size: 400
# Aligned data size: 400
# Aligned data size: 376
# Aligned data size: 376
# Aligned data size: 376
# Aligned data size: 400
# Aligned data size: 400
# Aligned data size: 400
# Aligned data size: 456
# Aligned data size: 456
# Aligned data size: 456
# Aligned data size: 536
# Aligned data size: 536
# Aligned data size: 536
# Aligned data size: 272
# Aligned data size: 272
# Aligned data size: 272
# Aligned data size: 296
# Aligned data size: 296
# Aligned data size: 296
# Aligned data size: 288
# Aligned data size: 288
# Aligned data size: 288
# Aligned data size: 336
# Aligned data size: 336
# Aligned data size: 336
# Aligned data size: 320
# Aligned data size: 320
# Aligned data size: 320
# Aligned data size: 464
# Aligned data size: 464
# Aligned data size: 464
# Aligned data size: 344
# Aligned data size: 344
# Aligned data size: 344
# Aligned data size: 224
# Aligned data size: 224
# Aligned data size: 224
# Aligned data size: 368
# Aligned data size: 368
# Aligned data size: 368
# Aligned data size: 352
# Aligned data size: 352
# Aligned data size: 352
# Aligned data size: 336
# Aligned data size: 336
# Aligned data size: 336
# Aligned data size: 448
# Aligned data size: 448
# Aligned data size: 448
# Aligned data size: 376
# Aligned data size: 376
# Aligned data size: 376
# Aligned data size: 438
# Aligned data size: 438
# Aligned data size: 438

# %%
def _load_trained_sae_models_(task):
  models={}
  base_dir=f"/content/drive/MyDrive/SAE_outputs/sae_checkpoints_{task}/"
  for layer_idx in range(num_layers):
    model_path = os.path.join(base_dir, f"layer_{layer_idx}_model.pt")
    checkpoint = torch.load(model_path, map_location=device)
    hidden_dim = checkpoint['encoder_state_dict']['weight'].shape[1]
    sae_dim = checkpoint['encoder_state_dict']['weight'].shape[0]

    encoder = torch.nn.Linear(hidden_dim, sae_dim, bias=True).to(device)
    encoder.load_state_dict(checkpoint['encoder_state_dict'])


    models[layer_idx] = {
        'encoder': encoder,
        'layer_idx': layer_idx
    }
  return models

# %%
tasks = ['pos','dep',"position"]


sae_models_results={}
if os.path.exists("last_task.txt"):
  with open("last_task.txt", "r") as f:
    completed_tasks=f.read().strip()

else:
  completed_tasks=''
  open("last_task.txt", "w")



for each_task in tasks:
  if each_task in completed_tasks.split(' '):
    continue

  try:
    print(f"started testing for task {each_task}")

    sae_models=_load_trained_sae_models_(each_task)
    sae_models_results[each_task]=_testing_all_encoders_(sae_models,hidden_states,all_task_alignedData[each_task],device,each_task)

  except KeyboardInterrupt:
          print(f"\nTraining interrupted at task {each_task}.")
          break
  with open("last_task.txt", "a") as f:
    f.write(each_task+' ')
# Out:
# started testing for task pos
#  Testing SAE for layer 0 of task 'pos'
#  Testing SAE for layer 1 of task 'pos'
#  Testing SAE for layer 2 of task 'pos'
#  Testing SAE for layer 3 of task 'pos'
#  Testing SAE for layer 4 of task 'pos'
#  Testing SAE for layer 5 of task 'pos'
# ✅ Finished testing all layers for task 'pos'
# started testing for task dep
#  Testing SAE for layer 0 of task 'dep'
#  Testing SAE for layer 1 of task 'dep'
#  Testing SAE for layer 2 of task 'dep'
#  Testing SAE for layer 3 of task 'dep'
#  Testing SAE for layer 4 of task 'dep'
#  Testing SAE for layer 5 of task 'dep'
# ✅ Finished testing all layers for task 'dep'
# started testing for task position
#  Testing SAE for layer 0 of task 'position'
#  Testing SAE for layer 1 of task 'position'
#  Testing SAE for layer 2 of task 'position'
#  Testing SAE for layer 3 of task 'position'
#  Testing SAE for layer 4 of task 'position'
#  Testing SAE for layer 5 of task 'position'
# ✅ Finished testing all layers for task 'position'

# %%
from collections import defaultdict, Counter

def summarize_labels_per_layer_across_tasks(sae_output):
    layer_label_map = defaultdict(list)  # {layer_idx: [dominant_labels from all tasks]}

    for task_data in sae_output.values():
        for layer_idx, layer_data in task_data.items():
            for feat in layer_data['interpretable_features']:
                label = feat['dominant_label']
                layer_label_map[layer_idx].append(label)

    print("GLOBAL SAE LAYER SUMMARY (All Tasks)\n")
    for layer_idx in sorted(layer_label_map.keys()):
        label_counts = Counter(layer_label_map[layer_idx])
        top_labels = label_counts.most_common(3)

        print(f"  Layer {layer_idx}:")
        print(f"   - Dominant label     : {top_labels[0][0]} ({top_labels[0][1]} features)")
        if len(top_labels) > 1:
            print("   - Other strong labels:")
            for label, count in top_labels[1:]:
                print(f"       - {label}: {count}")
        else:
            print("   - No other strong label")

        total_feats = sum(label_counts.values())
        print(f"  - Total features     : {total_feats}")
        print()

summarize_labels_per_layer_across_tasks(sae_models_results)
# Out:
# GLOBAL SAE LAYER SUMMARY (All Tasks)
#
#   Layer 0:
#    - Dominant label     : SPECIAL (30 features)
#    - No other strong label
#   - Total features     : 30
#
#   Layer 1:
#    - Dominant label     : SPECIAL (30 features)
#    - No other strong label
#   - Total features     : 30
#
#   Layer 2:
#    - Dominant label     : SPECIAL (25 features)
#    - Other strong labels:
#        - ADP: 1
#        - PROPN: 1
#   - Total features     : 30
#
#   Layer 3:
#    - Dominant label     : SPECIAL (28 features)
#    - Other strong labels:
#        - PUNCT: 1
#        - O: 1
#   - Total features     : 30
#
#   Layer 4:
#    - Dominant label     : SPECIAL (25 features)
#    - Other strong labels:
#        - O: 2
#        - DET: 1
#   - Total features     : 30
#
#   Layer 5:
#    - Dominant label     : SPECIAL (29 features)
#    - Other strong labels:
#        - O: 1
#   - Total features     : 30
